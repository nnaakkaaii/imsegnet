# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import init
import math 


class ResNet(nn.Module):
    def __init__(self, net):
        super().__init__()
        self.net = net

    def forward(self, x):
        return x + self.net(x)


class Conv2DBlock(nn.Module):
    def __init__(self, in_ch, out_ch, k, s=1, p=1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, k, s, p),
            nn.BatchNorm2d(out_ch),
            nn.ELU(),
        )

    def forward(self, x):
        return self.net(x)


class RepresentationNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(  # (1, 64, 64)
            Conv2DBlock(1, 128, 4, 2),  # (128, 32, 32)
            ResNet(Conv2DBlock(128, 128, 3)),
            Conv2DBlock(128, 256, 4, 2),  # (256, 16, 16)
            ResNet(Conv2DBlock(256, 256, 3)),
            Conv2DBlock(256, 512, 4, 2),  # (512, 8, 8)
            ResNet(Conv2DBlock(512, 512, 3)),
        )

    def forward(self, x):
        return self.net(x)


class TransformModule(nn.Module):
    def __init__(self):
        super().__init__()
        self.net1 = nn.Sequential(
            nn.Conv2d(512, 512, 1, 1, 0),  # (512, 8, 8)
            nn.ELU(),
        )
        self.net2 = nn.Sequential(
            nn.ConvTranspose3d(512, 512, 1, 1, 0),  # (512, 8, 8, 1)
            nn.ELU(),
        )

    def forward(self, x):
        x = self.net1(x)
        x = x.view(-1, 512, 8, 8, 1)
        x = self.net2(x)
        return x


class Deconv3DBlock(nn.Module):
    def __init__(self, in_ch, out_ch, k, s=1, p=1):
        super().__init__()
        self.net = nn.Sequential(
            nn.ConvTranspose3d(in_ch, out_ch, k, s, p),
            nn.BatchNorm3d(out_ch),
            nn.ELU(),
        )

    def forward(self, x):
        return self.net(x)


class GenerationNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(  # (512, 8, 8, 1)
            Deconv3DBlock(512, 256, 4, 2),  # (256, 16, 16, 2)
            Deconv3DBlock(256, 256, 3),
            Deconv3DBlock(256, 128, 4, 2),  # (128, 32, 32, 4)
            Deconv3DBlock(128, 128, 3),
            Deconv3DBlock(128, 64, 4, 2),  # (64, 64, 64, 8)
            Deconv3DBlock(64, 64, 3),
            nn.Conv3d(64, 1, 1, 1, 0),  # (1, 64, 64, 8)
        )

    def forward(self, x):
        return self.net(x)


class ReconstructionNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            RepresentationNetwork(),
            TransformModule(),
            GenerationNetwork(),
        )

    def forward(self, x):
        return self.net(x)

# %%
import torch
import numpy as np
import nibabel as ni
import os, shutil
import time
import random
import pandas as pd 

def split_train_test(dir, ratio_test=0.15):
    if os.path.exists(os.path.join(dir, "train")):
        return
    os.mkdir(os.path.join(dir, "train"))
    if not os.path.exists(os.path.join(dir, "test")):
        return
    os.mkdir(os.path.join(dir, "test"))
    
    images_list = [i for i in os.listdir(dir) if i.endswith(".nii")]

    random.shuffle(images_list)
    threshold = int(len(images_list)*ratio_test)
    train_list = images_list[:-threshold]
    test_list = images_list[-threshold:]

    for i in train_list:
        shutil.move(os.path.join(dir, i), os.path.join(dir, "train", i))
    for i in test_list:
        shutil.move(os.path.join(dir, i), os.path.join(dir, "test", i))

def save_data_to_csv(dir, z):
    pd.DataFrame(z).to_csv(dir, header=None, index=False)

def load_mri_images(path, batch_size):
    filenames = [i for i in os.listdir(path) if i.endswith("orig.nii")]
    random.shuffle(filenames)
    n = 0
    pool = nn.AvgPool3d(8)
    while n < len(filenames):
        batch_image = []
        for i in range(n, n + batch_size):
            if i >= len(filenames):
                ##n = i
                break
            image = ni.load(os.path.join(path, filenames[i]))
            image = np.array(image.dataobj)
            depth = image.shape[2]
            image = torch.Tensor(image)[:, :, depth//2-32:depth//2+32]  # (512, 512, 64)
            image = image / 255.
            image = torch.reshape(image, (1, 1, 512, 512, 64))
            image = pool(image)  # (64, 64, 8)
            batch_image.append(image)
        n += batch_size
        batch_image = torch.cat(batch_image, axis=0)
        yield batch_image

# %%
start = time.time()
for i in load_mri_images("../ircad-dataset/train/", 2):
    print(time.time()-start)
    start = time.time()
    print(i.shape)

split_train_test("../ircad-dataset")
# Out:
# 0.2172105312347412
# torch.Size([2, 1, 64, 64, 8])
# 0.23964571952819824
# torch.Size([2, 1, 64, 64, 8])
# 0.1983482837677002
# torch.Size([2, 1, 64, 64, 8])
# 0.20201921463012695
# torch.Size([2, 1, 64, 64, 8])
# 0.1908247470855713
# torch.Size([2, 1, 64, 64, 8])
# 0.2042698860168457
# torch.Size([2, 1, 64, 64, 8])
# 0.18651056289672852
# torch.Size([2, 1, 64, 64, 8])
# 0.17685508728027344
# torch.Size([2, 1, 64, 64, 8])

# %%
"""
Author: Duy-Phuong Dao
Email: phuongdd.1997@gmail.com (or duyphuongcri@gmail.com)
"""

import nibabel as ni
import numpy as np
import os, glob
import torch
import csv
import random
from tqdm import tqdm

##---------Settings--------------------------
batch_size = 64
lrate = 0.01
epochs = 2000
weight_decay = 5e-7
##############
path_data = "../ircad-dataset/train"
path2save = "./checkpoint/model_epoch_{}.pt"
dir_info = './infor'       
f = open(os.path.join(dir_info,'model_t1.csv'),'w',newline='')


####################
log = print
np.random.seed(10)
torch.manual_seed(10)
###################
criterion = nn.MSELoss()

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(" GPU is activated" if device else " CPU is activated")
no_images = len(glob.glob(path_data + "/*.nii"))
print("Number of MRI images: ", no_images)

model = ReconstructionNetwork()
model.to(device)
#log(vae_model)
optimizer = torch.optim.Adam(model.parameters(), lr=lrate, weight_decay=weight_decay)
for epoch in range(epochs):
    loss_epoch = 0
    
    # training phrase
    model.train()
    for batch_images in load_mri_images(path_data, batch_size):
        optimizer.zero_grad()
        batch_images = batch_images.to(device)
        y = model(batch_images[:, :, :, :, 4])
        
        # Measure loss
        loss = criterion(batch_images, y)

        # Optimize
        loss.backward()
        optimizer.step()
        
        loss_epoch += loss.item() * batch_images.shape[0]

    # save model
    log_info = (epoch + 1, epochs, loss_epoch/no_images)
    log('%d/%d  Reconstruction Loss %.3f'% log_info)
    torch.save(model, path2save.format(epoch+1))  

    # write csv
    writer = csv.writer(f)
    writer.writerow([epoch + 1, '{:04f}'.format(loss_epoch/no_images)])
f.close()
# Out:
#  GPU is activated
# Number of MRI images:  34
# 1/2000  Reconstruction Loss 4.161
# 2/2000  Reconstruction Loss 6.113
# 3/2000  Reconstruction Loss 4.087
# 4/2000  Reconstruction Loss 2.617
# 5/2000  Reconstruction Loss 2.323
# 6/2000  Reconstruction Loss 2.165
# 7/2000  Reconstruction Loss 2.039
# 8/2000  Reconstruction Loss 1.911
# 9/2000  Reconstruction Loss 1.774
# 10/2000  Reconstruction Loss 1.635
# 11/2000  Reconstruction Loss 1.503
# 12/2000  Reconstruction Loss 1.384
# 13/2000  Reconstruction Loss 1.281
# 14/2000  Reconstruction Loss 1.194
# 15/2000  Reconstruction Loss 1.116
# 16/2000  Reconstruction Loss 1.038
# 17/2000  Reconstruction Loss 0.953
# 18/2000  Reconstruction Loss 0.863
# 19/2000  Reconstruction Loss 0.781
# 20/2000  Reconstruction Loss 0.725
# 21/2000  Reconstruction Loss 0.696
# 22/2000  Reconstruction Loss 0.682
# 23/2000  Reconstruction Loss 0.668
# 24/2000  Reconstruction Loss 0.647
# 25/2000  Reconstruction Loss 0.625
# 26/2000  Reconstruction Loss 0.610
# 27/2000  Reconstruction Loss 0.603
# 28/2000  Reconstruction Loss 0.602
# 29/2000  Reconstruction Loss 0.603
# 30/2000  Reconstruction Loss 0.602
# 31/2000  Reconstruction Loss 0.598
# 32/2000  Reconstruction Loss 0.592
# 33/2000  Reconstruction Loss 0.585
# 34/2000  Reconstruction Loss 0.578
# 35/2000  Reconstruction Loss 0.570
# 36/2000  Reconstruction Loss 0.560
# 37/2000  Reconstruction Loss 0.551
# 38/2000  Reconstruction Loss 0.542
# 39/2000  Reconstruction Loss 0.534
# 40/2000  Reconstruction Loss 0.526
# 41/2000  Reconstruction Loss 0.519
# 42/2000  Reconstruction Loss 0.512
# 43/2000  Reconstruction Loss 0.507
# 44/2000  Reconstruction Loss 0.504
# 45/2000  Reconstruction Loss 0.502
# 46/2000  Reconstruction Loss 0.500
# 47/2000  Reconstruction Loss 0.498
# 48/2000  Reconstruction Loss 0.496
# 49/2000  Reconstruction Loss 0.494
# 50/2000  Reconstruction Loss 0.493
# 51/2000  Reconstruction Loss 0.491
# 52/2000  Reconstruction Loss 0.489
# 53/2000  Reconstruction Loss 0.486
# 54/2000  Reconstruction Loss 0.484
# 55/2000  Reconstruction Loss 0.482
# 56/2000  Reconstruction Loss 0.480
# 57/2000  Reconstruction Loss 0.479
# 58/2000  Reconstruction Loss 0.477
# 59/2000  Reconstruction Loss 0.476
# 60/2000  Reconstruction Loss 0.474
# 61/2000  Reconstruction Loss 0.473
# 62/2000  Reconstruction Loss 0.472
# 63/2000  Reconstruction Loss 0.470
# 64/2000  Reconstruction Loss 0.469
# 65/2000  Reconstruction Loss 0.467
# 66/2000  Reconstruction Loss 0.466
# 67/2000  Reconstruction Loss 0.465
# 68/2000  Reconstruction Loss 0.464
# 69/2000  Reconstruction Loss 0.463
# 70/2000  Reconstruction Loss 0.462
# 71/2000  Reconstruction Loss 0.461
# 72/2000  Reconstruction Loss 0.460
# 73/2000  Reconstruction Loss 0.459
# 74/2000  Reconstruction Loss 0.458
# 75/2000  Reconstruction Loss 0.457
# 76/2000  Reconstruction Loss 0.456
# 77/2000  Reconstruction Loss 0.455
# 78/2000  Reconstruction Loss 0.454
# 79/2000  Reconstruction Loss 0.453
# 80/2000  Reconstruction Loss 0.452
# 81/2000  Reconstruction Loss 0.451
# 82/2000  Reconstruction Loss 0.450
# 83/2000  Reconstruction Loss 0.449
# 84/2000  Reconstruction Loss 0.449
# 85/2000  Reconstruction Loss 0.448
# 86/2000  Reconstruction Loss 0.447
# 87/2000  Reconstruction Loss 0.446
# 88/2000  Reconstruction Loss 0.445
# 89/2000  Reconstruction Loss 0.444
# 90/2000  Reconstruction Loss 0.443
# 91/2000  Reconstruction Loss 0.442
# 92/2000  Reconstruction Loss 0.441
# 93/2000  Reconstruction Loss 0.440
# 94/2000  Reconstruction Loss 0.439
# 95/2000  Reconstruction Loss 0.438
# 96/2000  Reconstruction Loss 0.437
# 97/2000  Reconstruction Loss 0.436
# 98/2000  Reconstruction Loss 0.435
# 99/2000  Reconstruction Loss 0.433
# 100/2000  Reconstruction Loss 0.432
# 101/2000  Reconstruction Loss 0.431
# 102/2000  Reconstruction Loss 0.430
# 103/2000  Reconstruction Loss 0.429
# 104/2000  Reconstruction Loss 0.428
# 105/2000  Reconstruction Loss 0.426
# 106/2000  Reconstruction Loss 0.425
# 107/2000  Reconstruction Loss 0.423
# 108/2000  Reconstruction Loss 0.422
# 109/2000  Reconstruction Loss 0.420
# 110/2000  Reconstruction Loss 0.419
# 111/2000  Reconstruction Loss 0.417
# 112/2000  Reconstruction Loss 0.415
# 113/2000  Reconstruction Loss 0.413
# 114/2000  Reconstruction Loss 0.412
# 115/2000  Reconstruction Loss 0.409
# 116/2000  Reconstruction Loss 0.407
# 117/2000  Reconstruction Loss 0.405
# 118/2000  Reconstruction Loss 0.403
# 119/2000  Reconstruction Loss 0.400
# 120/2000  Reconstruction Loss 0.398
# 121/2000  Reconstruction Loss 0.395
# 122/2000  Reconstruction Loss 0.393
# 123/2000  Reconstruction Loss 0.390
# 124/2000  Reconstruction Loss 0.387
# 125/2000  Reconstruction Loss 0.383
# 126/2000  Reconstruction Loss 0.380
# 127/2000  Reconstruction Loss 0.377
# 128/2000  Reconstruction Loss 0.373
# 129/2000  Reconstruction Loss 0.370
# 130/2000  Reconstruction Loss 0.366
# 131/2000  Reconstruction Loss 0.363
# 132/2000  Reconstruction Loss 0.359
# 133/2000  Reconstruction Loss 0.355
# 134/2000  Reconstruction Loss 0.351
# 135/2000  Reconstruction Loss 0.348
# 136/2000  Reconstruction Loss 0.344
# 137/2000  Reconstruction Loss 0.340
# 138/2000  Reconstruction Loss 0.336
# 139/2000  Reconstruction Loss 0.332
# 140/2000  Reconstruction Loss 0.328
# 141/2000  Reconstruction Loss 0.324
# 142/2000  Reconstruction Loss 0.320
# 143/2000  Reconstruction Loss 0.316
# 144/2000  Reconstruction Loss 0.312
# 145/2000  Reconstruction Loss 0.309
# 146/2000  Reconstruction Loss 0.307
# 147/2000  Reconstruction Loss 0.316
# 148/2000  Reconstruction Loss 0.328
# 149/2000  Reconstruction Loss 0.316
# 150/2000  Reconstruction Loss 0.310
# 151/2000  Reconstruction Loss 0.321
# 152/2000  Reconstruction Loss 0.302
# 153/2000  Reconstruction Loss 0.308
# 154/2000  Reconstruction Loss 0.304
# 155/2000  Reconstruction Loss 0.299
# 156/2000  Reconstruction Loss 0.299
# 157/2000  Reconstruction Loss 0.289
# 158/2000  Reconstruction Loss 0.296
# 159/2000  Reconstruction Loss 0.284
# 160/2000  Reconstruction Loss 0.287
# 161/2000  Reconstruction Loss 0.287
# 162/2000  Reconstruction Loss 0.280
# 163/2000  Reconstruction Loss 0.284
# 164/2000  Reconstruction Loss 0.276
# 165/2000  Reconstruction Loss 0.279
# 166/2000  Reconstruction Loss 0.276
# 167/2000  Reconstruction Loss 0.275
# 168/2000  Reconstruction Loss 0.271
# 169/2000  Reconstruction Loss 0.269
# 170/2000  Reconstruction Loss 0.268
# 171/2000  Reconstruction Loss 0.264
# 172/2000  Reconstruction Loss 0.265
# 173/2000  Reconstruction Loss 0.261
# 174/2000  Reconstruction Loss 0.261
# 175/2000  Reconstruction Loss 0.258
# 176/2000  Reconstruction Loss 0.257
# 177/2000  Reconstruction Loss 0.256
# 178/2000  Reconstruction Loss 0.256
# 179/2000  Reconstruction Loss 0.262
# 180/2000  Reconstruction Loss 0.286
# 181/2000  Reconstruction Loss 0.326
# 182/2000  Reconstruction Loss 0.299
# 183/2000  Reconstruction Loss 0.258
# 184/2000  Reconstruction Loss 0.282
# 185/2000  Reconstruction Loss 0.258
# 186/2000  Reconstruction Loss 0.271
# 187/2000  Reconstruction Loss 0.257
# 188/2000  Reconstruction Loss 0.262
# 189/2000  Reconstruction Loss 0.254
# 190/2000  Reconstruction Loss 0.259
# 191/2000  Reconstruction Loss 0.251
# 192/2000  Reconstruction Loss 0.250
# 193/2000  Reconstruction Loss 0.249
# 194/2000  Reconstruction Loss 0.246
# 195/2000  Reconstruction Loss 0.244
# 196/2000  Reconstruction Loss 0.243
# 197/2000  Reconstruction Loss 0.239
# 198/2000  Reconstruction Loss 0.240
# 199/2000  Reconstruction Loss 0.236
# 200/2000  Reconstruction Loss 0.237
# 201/2000  Reconstruction Loss 0.238
# 202/2000  Reconstruction Loss 0.232
# 203/2000  Reconstruction Loss 0.237
# 204/2000  Reconstruction Loss 0.231
# 205/2000  Reconstruction Loss 0.232
# 206/2000  Reconstruction Loss 0.229
# 207/2000  Reconstruction Loss 0.231
# 208/2000  Reconstruction Loss 0.225
# 209/2000  Reconstruction Loss 0.226
# 210/2000  Reconstruction Loss 0.226
# 211/2000  Reconstruction Loss 0.223
# 212/2000  Reconstruction Loss 0.223
# 213/2000  Reconstruction Loss 0.220
# 214/2000  Reconstruction Loss 0.222
# 215/2000  Reconstruction Loss 0.220
# 216/2000  Reconstruction Loss 0.218
# 217/2000  Reconstruction Loss 0.219
# 218/2000  Reconstruction Loss 0.216
# 219/2000  Reconstruction Loss 0.217
# 220/2000  Reconstruction Loss 0.218
# 221/2000  Reconstruction Loss 0.216
# 222/2000  Reconstruction Loss 0.217
# 223/2000  Reconstruction Loss 0.213
# 224/2000  Reconstruction Loss 0.212
# 225/2000  Reconstruction Loss 0.213
# 226/2000  Reconstruction Loss 0.212
# 227/2000  Reconstruction Loss 0.212
# 228/2000  Reconstruction Loss 0.213
# 229/2000  Reconstruction Loss 0.211
# 230/2000  Reconstruction Loss 0.210
# 231/2000  Reconstruction Loss 0.212
# 232/2000  Reconstruction Loss 0.212
# 233/2000  Reconstruction Loss 0.214
# 234/2000  Reconstruction Loss 0.215
# 235/2000  Reconstruction Loss 0.211
# 236/2000  Reconstruction Loss 0.206
# 237/2000  Reconstruction Loss 0.204
# 238/2000  Reconstruction Loss 0.206
# 239/2000  Reconstruction Loss 0.209
# 240/2000  Reconstruction Loss 0.213
# 241/2000  Reconstruction Loss 0.215
# 242/2000  Reconstruction Loss 0.211
# 243/2000  Reconstruction Loss 0.203
# 244/2000  Reconstruction Loss 0.202
# 245/2000  Reconstruction Loss 0.205
# 246/2000  Reconstruction Loss 0.211
# 247/2000  Reconstruction Loss 0.212
# 248/2000  Reconstruction Loss 0.205
# 249/2000  Reconstruction Loss 0.200
# 250/2000  Reconstruction Loss 0.202
# 251/2000  Reconstruction Loss 0.209
# 252/2000  Reconstruction Loss 0.213
# 253/2000  Reconstruction Loss 0.203
# 254/2000  Reconstruction Loss 0.197
# 255/2000  Reconstruction Loss 0.203
# 256/2000  Reconstruction Loss 0.208
# 257/2000  Reconstruction Loss 0.201
# 258/2000  Reconstruction Loss 0.196
# 259/2000  Reconstruction Loss 0.201
# 260/2000  Reconstruction Loss 0.206
# 261/2000  Reconstruction Loss 0.200
# 262/2000  Reconstruction Loss 0.196
# 263/2000  Reconstruction Loss 0.197
# 264/2000  Reconstruction Loss 0.203
# 265/2000  Reconstruction Loss 0.196
# 266/2000  Reconstruction Loss 0.200
# 267/2000  Reconstruction Loss 0.201
# 268/2000  Reconstruction Loss 0.193
# 269/2000  Reconstruction Loss 0.199
# 270/2000  Reconstruction Loss 0.194
# 271/2000  Reconstruction Loss 0.196
# 272/2000  Reconstruction Loss 0.195
# 273/2000  Reconstruction Loss 0.196
# 274/2000  Reconstruction Loss 0.198
# 275/2000  Reconstruction Loss 0.193
# 276/2000  Reconstruction Loss 0.192
# 277/2000  Reconstruction Loss 0.189
# 278/2000  Reconstruction Loss 0.190
# 279/2000  Reconstruction Loss 0.189
# 280/2000  Reconstruction Loss 0.190
# 281/2000  Reconstruction Loss 0.190
# 282/2000  Reconstruction Loss 0.193
# 283/2000  Reconstruction Loss 0.196
# 284/2000  Reconstruction Loss 0.213
# 285/2000  Reconstruction Loss 0.223
# 286/2000  Reconstruction Loss 0.207
# 287/2000  Reconstruction Loss 0.189
# 288/2000  Reconstruction Loss 0.201
# 289/2000  Reconstruction Loss 0.205
# 290/2000  Reconstruction Loss 0.191
# 291/2000  Reconstruction Loss 0.192
# 292/2000  Reconstruction Loss 0.197
# 293/2000  Reconstruction Loss 0.187
# 294/2000  Reconstruction Loss 0.185
# 295/2000  Reconstruction Loss 0.193
# 296/2000  Reconstruction Loss 0.187
# 297/2000  Reconstruction Loss 0.185
# 298/2000  Reconstruction Loss 0.189
# 299/2000  Reconstruction Loss 0.189
# 300/2000  Reconstruction Loss 0.181
# 301/2000  Reconstruction Loss 0.181
# 302/2000  Reconstruction Loss 0.184
# 303/2000  Reconstruction Loss 0.181
# 304/2000  Reconstruction Loss 0.180
# 305/2000  Reconstruction Loss 0.180
# 306/2000  Reconstruction Loss 0.179
# 307/2000  Reconstruction Loss 0.180
# 308/2000  Reconstruction Loss 0.177
# 309/2000  Reconstruction Loss 0.176
# 310/2000  Reconstruction Loss 0.176
# 311/2000  Reconstruction Loss 0.178
# 312/2000  Reconstruction Loss 0.177
# 313/2000  Reconstruction Loss 0.174
# 314/2000  Reconstruction Loss 0.174
# 315/2000  Reconstruction Loss 0.174
# 316/2000  Reconstruction Loss 0.173
# 317/2000  Reconstruction Loss 0.172
# 318/2000  Reconstruction Loss 0.173
# 319/2000  Reconstruction Loss 0.174
# 320/2000  Reconstruction Loss 0.176
# 321/2000  Reconstruction Loss 0.175
# 322/2000  Reconstruction Loss 0.175
# 323/2000  Reconstruction Loss 0.171
# 324/2000  Reconstruction Loss 0.169
# 325/2000  Reconstruction Loss 0.172
# 326/2000  Reconstruction Loss 0.173
# 327/2000  Reconstruction Loss 0.176
# 328/2000  Reconstruction Loss 0.180
# 329/2000  Reconstruction Loss 0.201
# 330/2000  Reconstruction Loss 0.231
# 331/2000  Reconstruction Loss 0.249
# 332/2000  Reconstruction Loss 0.207
# 333/2000  Reconstruction Loss 0.207
# 334/2000  Reconstruction Loss 0.218
# 335/2000  Reconstruction Loss 0.195
# 336/2000  Reconstruction Loss 0.213
# 337/2000  Reconstruction Loss 0.189
# 338/2000  Reconstruction Loss 0.199
# 339/2000  Reconstruction Loss 0.193
# 340/2000  Reconstruction Loss 0.188
# 341/2000  Reconstruction Loss 0.191
# 342/2000  Reconstruction Loss 0.179
# 343/2000  Reconstruction Loss 0.191
# 344/2000  Reconstruction Loss 0.177
# 345/2000  Reconstruction Loss 0.183
# 346/2000  Reconstruction Loss 0.179
# 347/2000  Reconstruction Loss 0.176
# 348/2000  Reconstruction Loss 0.179
# 349/2000  Reconstruction Loss 0.173
# 350/2000  Reconstruction Loss 0.172
# 351/2000  Reconstruction Loss 0.174
# 352/2000  Reconstruction Loss 0.170
# 353/2000  Reconstruction Loss 0.171
# 354/2000  Reconstruction Loss 0.169
# 355/2000  Reconstruction Loss 0.168
# 356/2000  Reconstruction Loss 0.169
# 357/2000  Reconstruction Loss 0.166
# 358/2000  Reconstruction Loss 0.166
# 359/2000  Reconstruction Loss 0.166
# 360/2000  Reconstruction Loss 0.163
# 361/2000  Reconstruction Loss 0.164
# 362/2000  Reconstruction Loss 0.163
# 363/2000  Reconstruction Loss 0.162
# 364/2000  Reconstruction Loss 0.162
# 365/2000  Reconstruction Loss 0.162
# 366/2000  Reconstruction Loss 0.160
# 367/2000  Reconstruction Loss 0.161
# 368/2000  Reconstruction Loss 0.163
# 369/2000  Reconstruction Loss 0.163
# 370/2000  Reconstruction Loss 0.166
# 371/2000  Reconstruction Loss 0.161
# 372/2000  Reconstruction Loss 0.160
# 373/2000  Reconstruction Loss 0.160
# 374/2000  Reconstruction Loss 0.161
# 375/2000  Reconstruction Loss 0.161
# 376/2000  Reconstruction Loss 0.158
# 377/2000  Reconstruction Loss 0.156
# 378/2000  Reconstruction Loss 0.156
# 379/2000  Reconstruction Loss 0.157
# 380/2000  Reconstruction Loss 0.159
# 381/2000  Reconstruction Loss 0.161
# 382/2000  Reconstruction Loss 0.166
# 383/2000  Reconstruction Loss 0.157
# 384/2000  Reconstruction Loss 0.157
# 385/2000  Reconstruction Loss 0.162
# 386/2000  Reconstruction Loss 0.154
# 387/2000  Reconstruction Loss 0.156
# 388/2000  Reconstruction Loss 0.159
# 389/2000  Reconstruction Loss 0.153
# 390/2000  Reconstruction Loss 0.158
# 391/2000  Reconstruction Loss 0.165
# 392/2000  Reconstruction Loss 0.159
# 393/2000  Reconstruction Loss 0.172
# 394/2000  Reconstruction Loss 0.166
# 395/2000  Reconstruction Loss 0.160
# 396/2000  Reconstruction Loss 0.159
# 397/2000  Reconstruction Loss 0.153
# 398/2000  Reconstruction Loss 0.158
# 399/2000  Reconstruction Loss 0.154
# 400/2000  Reconstruction Loss 0.154
# 401/2000  Reconstruction Loss 0.150
# 402/2000  Reconstruction Loss 0.153
# 403/2000  Reconstruction Loss 0.152
# 404/2000  Reconstruction Loss 0.150
# 405/2000  Reconstruction Loss 0.152
# 406/2000  Reconstruction Loss 0.150
# 407/2000  Reconstruction Loss 0.153
# 408/2000  Reconstruction Loss 0.161
# 409/2000  Reconstruction Loss 0.174
# 410/2000  Reconstruction Loss 0.194
# 411/2000  Reconstruction Loss 0.180
# 412/2000  Reconstruction Loss 0.164
# 413/2000  Reconstruction Loss 0.174
# 414/2000  Reconstruction Loss 0.174
# 415/2000  Reconstruction Loss 0.170
# 416/2000  Reconstruction Loss 0.171
# 417/2000  Reconstruction Loss 0.161
# 418/2000  Reconstruction Loss 0.164
# 419/2000  Reconstruction Loss 0.156
# 420/2000  Reconstruction Loss 0.159
# 421/2000  Reconstruction Loss 0.153
# 422/2000  Reconstruction Loss 0.156
# 423/2000  Reconstruction Loss 0.152
# 424/2000  Reconstruction Loss 0.153
# 425/2000  Reconstruction Loss 0.149
# 426/2000  Reconstruction Loss 0.152
# 427/2000  Reconstruction Loss 0.150
# 428/2000  Reconstruction Loss 0.149
# 429/2000  Reconstruction Loss 0.149
# 430/2000  Reconstruction Loss 0.148
# 431/2000  Reconstruction Loss 0.147
# 432/2000  Reconstruction Loss 0.144
# 433/2000  Reconstruction Loss 0.146
# 434/2000  Reconstruction Loss 0.143
# 435/2000  Reconstruction Loss 0.143
# 436/2000  Reconstruction Loss 0.143
# 437/2000  Reconstruction Loss 0.143
# 438/2000  Reconstruction Loss 0.140
# 439/2000  Reconstruction Loss 0.141
# 440/2000  Reconstruction Loss 0.141
# 441/2000  Reconstruction Loss 0.141
# 442/2000  Reconstruction Loss 0.142
# 443/2000  Reconstruction Loss 0.149
# 444/2000  Reconstruction Loss 0.160
# 445/2000  Reconstruction Loss 0.155
# 446/2000  Reconstruction Loss 0.153
# 447/2000  Reconstruction Loss 0.145
# 448/2000  Reconstruction Loss 0.143
# 449/2000  Reconstruction Loss 0.143
# 450/2000  Reconstruction Loss 0.145
# 451/2000  Reconstruction Loss 0.144
# 452/2000  Reconstruction Loss 0.140
# 453/2000  Reconstruction Loss 0.138
# 454/2000  Reconstruction Loss 0.136
# 455/2000  Reconstruction Loss 0.139
# 456/2000  Reconstruction Loss 0.139
# 457/2000  Reconstruction Loss 0.137
# 458/2000  Reconstruction Loss 0.142
# 459/2000  Reconstruction Loss 0.147
# 460/2000  Reconstruction Loss 0.165
# 461/2000  Reconstruction Loss 0.162
# 462/2000  Reconstruction Loss 0.152
# 463/2000  Reconstruction Loss 0.155
# 464/2000  Reconstruction Loss 0.152
# 465/2000  Reconstruction Loss 0.148
# 466/2000  Reconstruction Loss 0.149
# 467/2000  Reconstruction Loss 0.170
# 468/2000  Reconstruction Loss 0.158
# 469/2000  Reconstruction Loss 0.176
# 470/2000  Reconstruction Loss 0.164
# 471/2000  Reconstruction Loss 0.159
# 472/2000  Reconstruction Loss 0.154
# 473/2000  Reconstruction Loss 0.153
# 474/2000  Reconstruction Loss 0.158
# 475/2000  Reconstruction Loss 0.148
# 476/2000  Reconstruction Loss 0.144
# 477/2000  Reconstruction Loss 0.145
# 478/2000  Reconstruction Loss 0.148
# 479/2000  Reconstruction Loss 0.145
# 480/2000  Reconstruction Loss 0.146
# 481/2000  Reconstruction Loss 0.141
# 482/2000  Reconstruction Loss 0.140
# 483/2000  Reconstruction Loss 0.140
# 484/2000  Reconstruction Loss 0.138
# 485/2000  Reconstruction Loss 0.138
# 486/2000  Reconstruction Loss 0.136
# 487/2000  Reconstruction Loss 0.134
# 488/2000  Reconstruction Loss 0.133
# 489/2000  Reconstruction Loss 0.134
# 490/2000  Reconstruction Loss 0.136
# 491/2000  Reconstruction Loss 0.137
# 492/2000  Reconstruction Loss 0.140
# 493/2000  Reconstruction Loss 0.136
# 494/2000  Reconstruction Loss 0.130
# 495/2000  Reconstruction Loss 0.131
# 496/2000  Reconstruction Loss 0.130
# 497/2000  Reconstruction Loss 0.131
# 498/2000  Reconstruction Loss 0.132
# 499/2000  Reconstruction Loss 0.132
# 500/2000  Reconstruction Loss 0.131
# 501/2000  Reconstruction Loss 0.129
# 502/2000  Reconstruction Loss 0.126
# 503/2000  Reconstruction Loss 0.126
# 504/2000  Reconstruction Loss 0.127
# 505/2000  Reconstruction Loss 0.130
# 506/2000  Reconstruction Loss 0.131
# 507/2000  Reconstruction Loss 0.132
# 508/2000  Reconstruction Loss 0.134
# 509/2000  Reconstruction Loss 0.141
# 510/2000  Reconstruction Loss 0.145
# 511/2000  Reconstruction Loss 0.136
# 512/2000  Reconstruction Loss 0.124
# 513/2000  Reconstruction Loss 0.126
# 514/2000  Reconstruction Loss 0.134
# 515/2000  Reconstruction Loss 0.136
# 516/2000  Reconstruction Loss 0.132
# 517/2000  Reconstruction Loss 0.130
# 518/2000  Reconstruction Loss 0.129
# 519/2000  Reconstruction Loss 0.131
# 520/2000  Reconstruction Loss 0.125
# 521/2000  Reconstruction Loss 0.123
# 522/2000  Reconstruction Loss 0.126
# 523/2000  Reconstruction Loss 0.124
# 524/2000  Reconstruction Loss 0.126
# 525/2000  Reconstruction Loss 0.121
# 526/2000  Reconstruction Loss 0.123
# 527/2000  Reconstruction Loss 0.128
# 528/2000  Reconstruction Loss 0.123
# 529/2000  Reconstruction Loss 0.123
# 530/2000  Reconstruction Loss 0.123
# 531/2000  Reconstruction Loss 0.121
# 532/2000  Reconstruction Loss 0.128
# 533/2000  Reconstruction Loss 0.124
# 534/2000  Reconstruction Loss 0.122
# 535/2000  Reconstruction Loss 0.120
# 536/2000  Reconstruction Loss 0.121
# 537/2000  Reconstruction Loss 0.121
# 538/2000  Reconstruction Loss 0.121
# 539/2000  Reconstruction Loss 0.120
# 540/2000  Reconstruction Loss 0.120
# 541/2000  Reconstruction Loss 0.118
# 542/2000  Reconstruction Loss 0.115
# 543/2000  Reconstruction Loss 0.114
# 544/2000  Reconstruction Loss 0.113
# 545/2000  Reconstruction Loss 0.113
# 546/2000  Reconstruction Loss 0.112
# 547/2000  Reconstruction Loss 0.112
# 548/2000  Reconstruction Loss 0.113
# 549/2000  Reconstruction Loss 0.116
# 550/2000  Reconstruction Loss 0.120
# 551/2000  Reconstruction Loss 0.132
# 552/2000  Reconstruction Loss 0.132
# 553/2000  Reconstruction Loss 0.123
# 554/2000  Reconstruction Loss 0.125
# 555/2000  Reconstruction Loss 0.124
# 556/2000  Reconstruction Loss 0.121
# 557/2000  Reconstruction Loss 0.125
# 558/2000  Reconstruction Loss 0.125
# 559/2000  Reconstruction Loss 0.120
# 560/2000  Reconstruction Loss 0.119
# 561/2000  Reconstruction Loss 0.117
# 562/2000  Reconstruction Loss 0.118
# 563/2000  Reconstruction Loss 0.118
# 564/2000  Reconstruction Loss 0.113
# 565/2000  Reconstruction Loss 0.115
# 566/2000  Reconstruction Loss 0.114
# 567/2000  Reconstruction Loss 0.110
# 568/2000  Reconstruction Loss 0.114
# 569/2000  Reconstruction Loss 0.109
# 570/2000  Reconstruction Loss 0.110
# 571/2000  Reconstruction Loss 0.112
# 572/2000  Reconstruction Loss 0.109
# 573/2000  Reconstruction Loss 0.112
# 574/2000  Reconstruction Loss 0.109
# 575/2000  Reconstruction Loss 0.107
# 576/2000  Reconstruction Loss 0.111
# 577/2000  Reconstruction Loss 0.118
# 578/2000  Reconstruction Loss 0.133
# 579/2000  Reconstruction Loss 0.140
# 580/2000  Reconstruction Loss 0.130
# 581/2000  Reconstruction Loss 0.116
# 582/2000  Reconstruction Loss 0.117
# 583/2000  Reconstruction Loss 0.117
# 584/2000  Reconstruction Loss 0.120
# 585/2000  Reconstruction Loss 0.115
# 586/2000  Reconstruction Loss 0.111
# 587/2000  Reconstruction Loss 0.109
# 588/2000  Reconstruction Loss 0.111
# 589/2000  Reconstruction Loss 0.112
# 590/2000  Reconstruction Loss 0.112
# 591/2000  Reconstruction Loss 0.118
# 592/2000  Reconstruction Loss 0.128
# 593/2000  Reconstruction Loss 0.129
# 594/2000  Reconstruction Loss 0.121
# 595/2000  Reconstruction Loss 0.119
# 596/2000  Reconstruction Loss 0.117
# 597/2000  Reconstruction Loss 0.118
# 598/2000  Reconstruction Loss 0.115
# 599/2000  Reconstruction Loss 0.114
# 600/2000  Reconstruction Loss 0.117
# 601/2000  Reconstruction Loss 0.113
# 602/2000  Reconstruction Loss 0.110
# 603/2000  Reconstruction Loss 0.110
# 604/2000  Reconstruction Loss 0.108
# 605/2000  Reconstruction Loss 0.109
# 606/2000  Reconstruction Loss 0.108
# 607/2000  Reconstruction Loss 0.107
# 608/2000  Reconstruction Loss 0.102
# 609/2000  Reconstruction Loss 0.105
# 610/2000  Reconstruction Loss 0.105
# 611/2000  Reconstruction Loss 0.104
# 612/2000  Reconstruction Loss 0.103
# 613/2000  Reconstruction Loss 0.102
# 614/2000  Reconstruction Loss 0.101
# 615/2000  Reconstruction Loss 0.102
# 616/2000  Reconstruction Loss 0.101
# 617/2000  Reconstruction Loss 0.102
# 618/2000  Reconstruction Loss 0.102
# 619/2000  Reconstruction Loss 0.101
# 620/2000  Reconstruction Loss 0.100
# 621/2000  Reconstruction Loss 0.100
# 622/2000  Reconstruction Loss 0.099
# 623/2000  Reconstruction Loss 0.099
# 624/2000  Reconstruction Loss 0.099
# 625/2000  Reconstruction Loss 0.099
# 626/2000  Reconstruction Loss 0.101
# 627/2000  Reconstruction Loss 0.102
# 628/2000  Reconstruction Loss 0.105
# 629/2000  Reconstruction Loss 0.101
# 630/2000  Reconstruction Loss 0.103
# 631/2000  Reconstruction Loss 0.104
# 632/2000  Reconstruction Loss 0.100
# 633/2000  Reconstruction Loss 0.101
# 634/2000  Reconstruction Loss 0.100
# 635/2000  Reconstruction Loss 0.102
# 636/2000  Reconstruction Loss 0.101
# 637/2000  Reconstruction Loss 0.102
# 638/2000  Reconstruction Loss 0.102
# 639/2000  Reconstruction Loss 0.101
# 640/2000  Reconstruction Loss 0.101
# 641/2000  Reconstruction Loss 0.104
# 642/2000  Reconstruction Loss 0.114
# 643/2000  Reconstruction Loss 0.125
# 644/2000  Reconstruction Loss 0.113
# 645/2000  Reconstruction Loss 0.117
# 646/2000  Reconstruction Loss 0.109
# 647/2000  Reconstruction Loss 0.111
# 648/2000  Reconstruction Loss 0.106
# 649/2000  Reconstruction Loss 0.111
# 650/2000  Reconstruction Loss 0.107
# 651/2000  Reconstruction Loss 0.105
# 652/2000  Reconstruction Loss 0.106
# 653/2000  Reconstruction Loss 0.105
# 654/2000  Reconstruction Loss 0.103
# 655/2000  Reconstruction Loss 0.100
# 656/2000  Reconstruction Loss 0.100
# 657/2000  Reconstruction Loss 0.102
# 658/2000  Reconstruction Loss 0.100
# 659/2000  Reconstruction Loss 0.099
# 660/2000  Reconstruction Loss 0.097
# 661/2000  Reconstruction Loss 0.096
# 662/2000  Reconstruction Loss 0.095
# 663/2000  Reconstruction Loss 0.096
# 664/2000  Reconstruction Loss 0.095
# 665/2000  Reconstruction Loss 0.097
# 666/2000  Reconstruction Loss 0.095
# 667/2000  Reconstruction Loss 0.093
# 668/2000  Reconstruction Loss 0.092
# 669/2000  Reconstruction Loss 0.091
# 670/2000  Reconstruction Loss 0.092
# 671/2000  Reconstruction Loss 0.091
# 672/2000  Reconstruction Loss 0.093
# 673/2000  Reconstruction Loss 0.094
# 674/2000  Reconstruction Loss 0.097
# 675/2000  Reconstruction Loss 0.107
# 676/2000  Reconstruction Loss 0.112
# 677/2000  Reconstruction Loss 0.112
# 678/2000  Reconstruction Loss 0.105
# 679/2000  Reconstruction Loss 0.136
# 680/2000  Reconstruction Loss 0.126
# 681/2000  Reconstruction Loss 0.128
# 682/2000  Reconstruction Loss 0.119
# 683/2000  Reconstruction Loss 0.117
# 684/2000  Reconstruction Loss 0.114
# 685/2000  Reconstruction Loss 0.112
# 686/2000  Reconstruction Loss 0.112
# 687/2000  Reconstruction Loss 0.106
# 688/2000  Reconstruction Loss 0.106
# 689/2000  Reconstruction Loss 0.107
# 690/2000  Reconstruction Loss 0.103
# 691/2000  Reconstruction Loss 0.101
# 692/2000  Reconstruction Loss 0.101
# 693/2000  Reconstruction Loss 0.099
# 694/2000  Reconstruction Loss 0.098
# 695/2000  Reconstruction Loss 0.095
# 696/2000  Reconstruction Loss 0.096
# 697/2000  Reconstruction Loss 0.096
# 698/2000  Reconstruction Loss 0.094
# 699/2000  Reconstruction Loss 0.094
# 700/2000  Reconstruction Loss 0.093
# 701/2000  Reconstruction Loss 0.091
# 702/2000  Reconstruction Loss 0.091
# 703/2000  Reconstruction Loss 0.091
# 704/2000  Reconstruction Loss 0.091
# 705/2000  Reconstruction Loss 0.090
# 706/2000  Reconstruction Loss 0.091
# 707/2000  Reconstruction Loss 0.091
# 708/2000  Reconstruction Loss 0.093
# 709/2000  Reconstruction Loss 0.097
# 710/2000  Reconstruction Loss 0.102
# 711/2000  Reconstruction Loss 0.103
# 712/2000  Reconstruction Loss 0.097
# 713/2000  Reconstruction Loss 0.090
# 714/2000  Reconstruction Loss 0.089
# 715/2000  Reconstruction Loss 0.089
# 716/2000  Reconstruction Loss 0.090
# 717/2000  Reconstruction Loss 0.092
# 718/2000  Reconstruction Loss 0.092
# 719/2000  Reconstruction Loss 0.088
# 720/2000  Reconstruction Loss 0.085
# 721/2000  Reconstruction Loss 0.086
# 722/2000  Reconstruction Loss 0.086
# 723/2000  Reconstruction Loss 0.086
# 724/2000  Reconstruction Loss 0.086
# 725/2000  Reconstruction Loss 0.086
# 726/2000  Reconstruction Loss 0.084
# 727/2000  Reconstruction Loss 0.083
# 728/2000  Reconstruction Loss 0.083
# 729/2000  Reconstruction Loss 0.083
# 730/2000  Reconstruction Loss 0.084
# 731/2000  Reconstruction Loss 0.084
# 732/2000  Reconstruction Loss 0.084
# 733/2000  Reconstruction Loss 0.084
# 734/2000  Reconstruction Loss 0.084
# 735/2000  Reconstruction Loss 0.085
# 736/2000  Reconstruction Loss 0.087
# 737/2000  Reconstruction Loss 0.090
# 738/2000  Reconstruction Loss 0.094
# 739/2000  Reconstruction Loss 0.087
# 740/2000  Reconstruction Loss 0.084
# 741/2000  Reconstruction Loss 0.086
# 742/2000  Reconstruction Loss 0.085
# 743/2000  Reconstruction Loss 0.083
# 744/2000  Reconstruction Loss 0.082
# 745/2000  Reconstruction Loss 0.083
# 746/2000  Reconstruction Loss 0.085
# 747/2000  Reconstruction Loss 0.085
# 748/2000  Reconstruction Loss 0.085
# 749/2000  Reconstruction Loss 0.087
# 750/2000  Reconstruction Loss 0.090
# 751/2000  Reconstruction Loss 0.089
# 752/2000  Reconstruction Loss 0.086
# 753/2000  Reconstruction Loss 0.085
# 754/2000  Reconstruction Loss 0.084
# 755/2000  Reconstruction Loss 0.082
# 756/2000  Reconstruction Loss 0.082
# 757/2000  Reconstruction Loss 0.082
# 758/2000  Reconstruction Loss 0.081
# 759/2000  Reconstruction Loss 0.083
# 760/2000  Reconstruction Loss 0.088
# 761/2000  Reconstruction Loss 0.098
# 762/2000  Reconstruction Loss 0.087
# 763/2000  Reconstruction Loss 0.093
# 764/2000  Reconstruction Loss 0.097
# 765/2000  Reconstruction Loss 0.089
# 766/2000  Reconstruction Loss 0.095
# 767/2000  Reconstruction Loss 0.085
# 768/2000  Reconstruction Loss 0.090
# 769/2000  Reconstruction Loss 0.086
# 770/2000  Reconstruction Loss 0.087
# 771/2000  Reconstruction Loss 0.086
# 772/2000  Reconstruction Loss 0.085
# 773/2000  Reconstruction Loss 0.083
# 774/2000  Reconstruction Loss 0.084
# 775/2000  Reconstruction Loss 0.081
# 776/2000  Reconstruction Loss 0.083
# 777/2000  Reconstruction Loss 0.079
# 778/2000  Reconstruction Loss 0.080
# 779/2000  Reconstruction Loss 0.079
# 780/2000  Reconstruction Loss 0.081
# 781/2000  Reconstruction Loss 0.080
# 782/2000  Reconstruction Loss 0.081
# 783/2000  Reconstruction Loss 0.081
# 784/2000  Reconstruction Loss 0.084
# 785/2000  Reconstruction Loss 0.086
# 786/2000  Reconstruction Loss 0.087
# 787/2000  Reconstruction Loss 0.088
# 788/2000  Reconstruction Loss 0.084
# 789/2000  Reconstruction Loss 0.079
# 790/2000  Reconstruction Loss 0.078
# 791/2000  Reconstruction Loss 0.080
# 792/2000  Reconstruction Loss 0.083
# 793/2000  Reconstruction Loss 0.081
# 794/2000  Reconstruction Loss 0.081
# 795/2000  Reconstruction Loss 0.080
# 796/2000  Reconstruction Loss 0.076
# 797/2000  Reconstruction Loss 0.076
# 798/2000  Reconstruction Loss 0.078
# 799/2000  Reconstruction Loss 0.077
# 800/2000  Reconstruction Loss 0.078
# 801/2000  Reconstruction Loss 0.081
# 802/2000  Reconstruction Loss 0.079
# 803/2000  Reconstruction Loss 0.076
# 804/2000  Reconstruction Loss 0.075
# 805/2000  Reconstruction Loss 0.075
# 806/2000  Reconstruction Loss 0.078
# 807/2000  Reconstruction Loss 0.079
# 808/2000  Reconstruction Loss 0.086
# 809/2000  Reconstruction Loss 0.087
# 810/2000  Reconstruction Loss 0.087
# 811/2000  Reconstruction Loss 0.082
# 812/2000  Reconstruction Loss 0.087
# 813/2000  Reconstruction Loss 0.096
# 814/2000  Reconstruction Loss 0.092
# 815/2000  Reconstruction Loss 0.093
# 816/2000  Reconstruction Loss 0.086
# 817/2000  Reconstruction Loss 0.089
# 818/2000  Reconstruction Loss 0.082
# 819/2000  Reconstruction Loss 0.084
# 820/2000  Reconstruction Loss 0.082
# 821/2000  Reconstruction Loss 0.080
# 822/2000  Reconstruction Loss 0.080
# 823/2000  Reconstruction Loss 0.078
# 824/2000  Reconstruction Loss 0.079
# 825/2000  Reconstruction Loss 0.076
# 826/2000  Reconstruction Loss 0.077
# 827/2000  Reconstruction Loss 0.075
# 828/2000  Reconstruction Loss 0.075
# 829/2000  Reconstruction Loss 0.074
# 830/2000  Reconstruction Loss 0.074
# 831/2000  Reconstruction Loss 0.075
# 832/2000  Reconstruction Loss 0.076
# 833/2000  Reconstruction Loss 0.080
# 834/2000  Reconstruction Loss 0.087
# 835/2000  Reconstruction Loss 0.090
# 836/2000  Reconstruction Loss 0.089
# 837/2000  Reconstruction Loss 0.081
# 838/2000  Reconstruction Loss 0.074
# 839/2000  Reconstruction Loss 0.071
# 840/2000  Reconstruction Loss 0.077
# 841/2000  Reconstruction Loss 0.079
# 842/2000  Reconstruction Loss 0.076
# 843/2000  Reconstruction Loss 0.071
# 844/2000  Reconstruction Loss 0.071
# 845/2000  Reconstruction Loss 0.073
# 846/2000  Reconstruction Loss 0.074
# 847/2000  Reconstruction Loss 0.072
# 848/2000  Reconstruction Loss 0.069
# 849/2000  Reconstruction Loss 0.069
# 850/2000  Reconstruction Loss 0.071
# 851/2000  Reconstruction Loss 0.070
# 852/2000  Reconstruction Loss 0.069
# 853/2000  Reconstruction Loss 0.068
# 854/2000  Reconstruction Loss 0.068
# 855/2000  Reconstruction Loss 0.069
# 856/2000  Reconstruction Loss 0.071
# 857/2000  Reconstruction Loss 0.074
# 858/2000  Reconstruction Loss 0.076
# 859/2000  Reconstruction Loss 0.086
# 860/2000  Reconstruction Loss 0.083
# 861/2000  Reconstruction Loss 0.094
# 862/2000  Reconstruction Loss 0.089
# 863/2000  Reconstruction Loss 0.099
# 864/2000  Reconstruction Loss 0.095
# 865/2000  Reconstruction Loss 0.094
# 866/2000  Reconstruction Loss 0.084
# 867/2000  Reconstruction Loss 0.087
# 868/2000  Reconstruction Loss 0.084
# 869/2000  Reconstruction Loss 0.085
# 870/2000  Reconstruction Loss 0.077
# 871/2000  Reconstruction Loss 0.081
# 872/2000  Reconstruction Loss 0.079
# 873/2000  Reconstruction Loss 0.079
# 874/2000  Reconstruction Loss 0.075
# 875/2000  Reconstruction Loss 0.075
# 876/2000  Reconstruction Loss 0.074
# 877/2000  Reconstruction Loss 0.073
# 878/2000  Reconstruction Loss 0.073
# 879/2000  Reconstruction Loss 0.072
# 880/2000  Reconstruction Loss 0.071
# 881/2000  Reconstruction Loss 0.070
# 882/2000  Reconstruction Loss 0.070
# 883/2000  Reconstruction Loss 0.068
# 884/2000  Reconstruction Loss 0.068
# 885/2000  Reconstruction Loss 0.068
# 886/2000  Reconstruction Loss 0.068
# 887/2000  Reconstruction Loss 0.067
# 888/2000  Reconstruction Loss 0.066
# 889/2000  Reconstruction Loss 0.066
# 890/2000  Reconstruction Loss 0.065
# 891/2000  Reconstruction Loss 0.065
# 892/2000  Reconstruction Loss 0.064
# 893/2000  Reconstruction Loss 0.064
# 894/2000  Reconstruction Loss 0.064
# 895/2000  Reconstruction Loss 0.064
# 896/2000  Reconstruction Loss 0.064
# 897/2000  Reconstruction Loss 0.064
# 898/2000  Reconstruction Loss 0.066
# 899/2000  Reconstruction Loss 0.069
# 900/2000  Reconstruction Loss 0.073
# 901/2000  Reconstruction Loss 0.077
# 902/2000  Reconstruction Loss 0.077
# 903/2000  Reconstruction Loss 0.076
# 904/2000  Reconstruction Loss 0.077
# 905/2000  Reconstruction Loss 0.075
# 906/2000  Reconstruction Loss 0.071
# 907/2000  Reconstruction Loss 0.070
# 908/2000  Reconstruction Loss 0.068
# 909/2000  Reconstruction Loss 0.067
# 910/2000  Reconstruction Loss 0.069
# 911/2000  Reconstruction Loss 0.065
# 912/2000  Reconstruction Loss 0.066
# 913/2000  Reconstruction Loss 0.068
# 914/2000  Reconstruction Loss 0.063
# 915/2000  Reconstruction Loss 0.063
# 916/2000  Reconstruction Loss 0.065
# 917/2000  Reconstruction Loss 0.064
# 918/2000  Reconstruction Loss 0.063
# 919/2000  Reconstruction Loss 0.062
# 920/2000  Reconstruction Loss 0.063
# 921/2000  Reconstruction Loss 0.062
# 922/2000  Reconstruction Loss 0.061
# 923/2000  Reconstruction Loss 0.061
# 924/2000  Reconstruction Loss 0.061
# 925/2000  Reconstruction Loss 0.062
# 926/2000  Reconstruction Loss 0.062
# 927/2000  Reconstruction Loss 0.063
# 928/2000  Reconstruction Loss 0.067
# 929/2000  Reconstruction Loss 0.071
# 930/2000  Reconstruction Loss 0.075
# 931/2000  Reconstruction Loss 0.070
# 932/2000  Reconstruction Loss 0.068
# 933/2000  Reconstruction Loss 0.070
# 934/2000  Reconstruction Loss 0.071
# 935/2000  Reconstruction Loss 0.070
# 936/2000  Reconstruction Loss 0.071
# 937/2000  Reconstruction Loss 0.071
# 938/2000  Reconstruction Loss 0.069
# 939/2000  Reconstruction Loss 0.067
# 940/2000  Reconstruction Loss 0.072
# 941/2000  Reconstruction Loss 0.066
# 942/2000  Reconstruction Loss 0.068
# 943/2000  Reconstruction Loss 0.066
# 944/2000  Reconstruction Loss 0.066
# 945/2000  Reconstruction Loss 0.065
# 946/2000  Reconstruction Loss 0.062
# 947/2000  Reconstruction Loss 0.064
# 948/2000  Reconstruction Loss 0.062
# 949/2000  Reconstruction Loss 0.061
# 950/2000  Reconstruction Loss 0.061
# 951/2000  Reconstruction Loss 0.061
# 952/2000  Reconstruction Loss 0.060
# 953/2000  Reconstruction Loss 0.060
# 954/2000  Reconstruction Loss 0.059
# 955/2000  Reconstruction Loss 0.059
# 956/2000  Reconstruction Loss 0.060
# 957/2000  Reconstruction Loss 0.059
# 958/2000  Reconstruction Loss 0.060
# 959/2000  Reconstruction Loss 0.059
# 960/2000  Reconstruction Loss 0.060
# 961/2000  Reconstruction Loss 0.060
# 962/2000  Reconstruction Loss 0.061
# 963/2000  Reconstruction Loss 0.061
# 964/2000  Reconstruction Loss 0.062
# 965/2000  Reconstruction Loss 0.062
# 966/2000  Reconstruction Loss 0.062
# 967/2000  Reconstruction Loss 0.060
# 968/2000  Reconstruction Loss 0.063
# 969/2000  Reconstruction Loss 0.061
# 970/2000  Reconstruction Loss 0.061
# 971/2000  Reconstruction Loss 0.057
# 972/2000  Reconstruction Loss 0.059
# 973/2000  Reconstruction Loss 0.061
# 974/2000  Reconstruction Loss 0.059
# 975/2000  Reconstruction Loss 0.059
# 976/2000  Reconstruction Loss 0.061
# 977/2000  Reconstruction Loss 0.059
# 978/2000  Reconstruction Loss 0.058
# 979/2000  Reconstruction Loss 0.059
# 980/2000  Reconstruction Loss 0.057
# 981/2000  Reconstruction Loss 0.056
# 982/2000  Reconstruction Loss 0.058
# 983/2000  Reconstruction Loss 0.057
# 984/2000  Reconstruction Loss 0.056
# 985/2000  Reconstruction Loss 0.058
# 986/2000  Reconstruction Loss 0.057
# 987/2000  Reconstruction Loss 0.056
# 988/2000  Reconstruction Loss 0.057
# 989/2000  Reconstruction Loss 0.056
# 990/2000  Reconstruction Loss 0.054
# 991/2000  Reconstruction Loss 0.055
# 992/2000  Reconstruction Loss 0.055
# 993/2000  Reconstruction Loss 0.055
# 994/2000  Reconstruction Loss 0.057
# 995/2000  Reconstruction Loss 0.062
# 996/2000  Reconstruction Loss 0.066
# 997/2000  Reconstruction Loss 0.067
# 998/2000  Reconstruction Loss 0.062
# 999/2000  Reconstruction Loss 0.059
# 1000/2000  Reconstruction Loss 0.060
# 1001/2000  Reconstruction Loss 0.059
# 1002/2000  Reconstruction Loss 0.060
# 1003/2000  Reconstruction Loss 0.056
# 1004/2000  Reconstruction Loss 0.054
# 1005/2000  Reconstruction Loss 0.058
# 1006/2000  Reconstruction Loss 0.057
# 1007/2000  Reconstruction Loss 0.054
# 1008/2000  Reconstruction Loss 0.054
# 1009/2000  Reconstruction Loss 0.056
# 1010/2000  Reconstruction Loss 0.054
# 1011/2000  Reconstruction Loss 0.055
# 1012/2000  Reconstruction Loss 0.055
# 1013/2000  Reconstruction Loss 0.055
# 1014/2000  Reconstruction Loss 0.058
# 1015/2000  Reconstruction Loss 0.067
# 1016/2000  Reconstruction Loss 0.062
# 1017/2000  Reconstruction Loss 0.064
# 1018/2000  Reconstruction Loss 0.068
# 1019/2000  Reconstruction Loss 0.060
# 1020/2000  Reconstruction Loss 0.064
# 1021/2000  Reconstruction Loss 0.063
# 1022/2000  Reconstruction Loss 0.064
# 1023/2000  Reconstruction Loss 0.059
# 1024/2000  Reconstruction Loss 0.061
# 1025/2000  Reconstruction Loss 0.057
# 1026/2000  Reconstruction Loss 0.058
# 1027/2000  Reconstruction Loss 0.054
# 1028/2000  Reconstruction Loss 0.056
# 1029/2000  Reconstruction Loss 0.053
# 1030/2000  Reconstruction Loss 0.054
# 1031/2000  Reconstruction Loss 0.052
# 1032/2000  Reconstruction Loss 0.053
# 1033/2000  Reconstruction Loss 0.052
# 1034/2000  Reconstruction Loss 0.053
# 1035/2000  Reconstruction Loss 0.053
# 1036/2000  Reconstruction Loss 0.058
# 1037/2000  Reconstruction Loss 0.058
# 1038/2000  Reconstruction Loss 0.059
# 1039/2000  Reconstruction Loss 0.054
# 1040/2000  Reconstruction Loss 0.055
# 1041/2000  Reconstruction Loss 0.056
# 1042/2000  Reconstruction Loss 0.056
# 1043/2000  Reconstruction Loss 0.054
# 1044/2000  Reconstruction Loss 0.056
# 1045/2000  Reconstruction Loss 0.057
# 1046/2000  Reconstruction Loss 0.054
# 1047/2000  Reconstruction Loss 0.051
# 1048/2000  Reconstruction Loss 0.053
# 1049/2000  Reconstruction Loss 0.051
# 1050/2000  Reconstruction Loss 0.050
# 1051/2000  Reconstruction Loss 0.050
# 1052/2000  Reconstruction Loss 0.050
# 1053/2000  Reconstruction Loss 0.049
# 1054/2000  Reconstruction Loss 0.049
# 1055/2000  Reconstruction Loss 0.049
# 1056/2000  Reconstruction Loss 0.049
# 1057/2000  Reconstruction Loss 0.050
# 1058/2000  Reconstruction Loss 0.049
# 1059/2000  Reconstruction Loss 0.049
# 1060/2000  Reconstruction Loss 0.051
# 1061/2000  Reconstruction Loss 0.053
# 1062/2000  Reconstruction Loss 0.055
# 1063/2000  Reconstruction Loss 0.060
# 1064/2000  Reconstruction Loss 0.061
# 1065/2000  Reconstruction Loss 0.062
# 1066/2000  Reconstruction Loss 0.056
# 1067/2000  Reconstruction Loss 0.053
# 1068/2000  Reconstruction Loss 0.056
# 1069/2000  Reconstruction Loss 0.055
# 1070/2000  Reconstruction Loss 0.055
# 1071/2000  Reconstruction Loss 0.054
# 1072/2000  Reconstruction Loss 0.052
# 1073/2000  Reconstruction Loss 0.051
# 1074/2000  Reconstruction Loss 0.050
# 1075/2000  Reconstruction Loss 0.052
# 1076/2000  Reconstruction Loss 0.052
# 1077/2000  Reconstruction Loss 0.050
# 1078/2000  Reconstruction Loss 0.051
# 1079/2000  Reconstruction Loss 0.047
# 1080/2000  Reconstruction Loss 0.049
# 1081/2000  Reconstruction Loss 0.049
# 1082/2000  Reconstruction Loss 0.049
# 1083/2000  Reconstruction Loss 0.050
# 1084/2000  Reconstruction Loss 0.049
# 1085/2000  Reconstruction Loss 0.049
# 1086/2000  Reconstruction Loss 0.047
# 1087/2000  Reconstruction Loss 0.047
# 1088/2000  Reconstruction Loss 0.047
# 1089/2000  Reconstruction Loss 0.048
# 1090/2000  Reconstruction Loss 0.047
# 1091/2000  Reconstruction Loss 0.046
# 1092/2000  Reconstruction Loss 0.047
# 1093/2000  Reconstruction Loss 0.047
# 1094/2000  Reconstruction Loss 0.047
# 1095/2000  Reconstruction Loss 0.047
# 1096/2000  Reconstruction Loss 0.046
# 1097/2000  Reconstruction Loss 0.045
# 1098/2000  Reconstruction Loss 0.045
# 1099/2000  Reconstruction Loss 0.045
# 1100/2000  Reconstruction Loss 0.047
# 1101/2000  Reconstruction Loss 0.047
# 1102/2000  Reconstruction Loss 0.048
# 1103/2000  Reconstruction Loss 0.048
# 1104/2000  Reconstruction Loss 0.048
# 1105/2000  Reconstruction Loss 0.050
# 1106/2000  Reconstruction Loss 0.050
# 1107/2000  Reconstruction Loss 0.053
# 1108/2000  Reconstruction Loss 0.054
# 1109/2000  Reconstruction Loss 0.054
# 1110/2000  Reconstruction Loss 0.051
# 1111/2000  Reconstruction Loss 0.047
# 1112/2000  Reconstruction Loss 0.048
# 1113/2000  Reconstruction Loss 0.052
# 1114/2000  Reconstruction Loss 0.053
# 1115/2000  Reconstruction Loss 0.049
# 1116/2000  Reconstruction Loss 0.048
# 1117/2000  Reconstruction Loss 0.047
# 1118/2000  Reconstruction Loss 0.047
# 1119/2000  Reconstruction Loss 0.045
# 1120/2000  Reconstruction Loss 0.045
# 1121/2000  Reconstruction Loss 0.045
# 1122/2000  Reconstruction Loss 0.045
# 1123/2000  Reconstruction Loss 0.043
# 1124/2000  Reconstruction Loss 0.044
# 1125/2000  Reconstruction Loss 0.043
# 1126/2000  Reconstruction Loss 0.043
# 1127/2000  Reconstruction Loss 0.042
# 1128/2000  Reconstruction Loss 0.043
# 1129/2000  Reconstruction Loss 0.043
# 1130/2000  Reconstruction Loss 0.043
# 1131/2000  Reconstruction Loss 0.042
# 1132/2000  Reconstruction Loss 0.043
# 1133/2000  Reconstruction Loss 0.044
# 1134/2000  Reconstruction Loss 0.045
# 1135/2000  Reconstruction Loss 0.046
# 1136/2000  Reconstruction Loss 0.046
# 1137/2000  Reconstruction Loss 0.046
# 1138/2000  Reconstruction Loss 0.044
# 1139/2000  Reconstruction Loss 0.046
# 1140/2000  Reconstruction Loss 0.049
# 1141/2000  Reconstruction Loss 0.056
# 1142/2000  Reconstruction Loss 0.047
# 1143/2000  Reconstruction Loss 0.051
# 1144/2000  Reconstruction Loss 0.055
# 1145/2000  Reconstruction Loss 0.046
# 1146/2000  Reconstruction Loss 0.051
# 1147/2000  Reconstruction Loss 0.052
# 1148/2000  Reconstruction Loss 0.049
# 1149/2000  Reconstruction Loss 0.050
# 1150/2000  Reconstruction Loss 0.047
# 1151/2000  Reconstruction Loss 0.048
# 1152/2000  Reconstruction Loss 0.047
# 1153/2000  Reconstruction Loss 0.046
# 1154/2000  Reconstruction Loss 0.046
# 1155/2000  Reconstruction Loss 0.045
# 1156/2000  Reconstruction Loss 0.044
# 1157/2000  Reconstruction Loss 0.043
# 1158/2000  Reconstruction Loss 0.044
# 1159/2000  Reconstruction Loss 0.043
# 1160/2000  Reconstruction Loss 0.044
# 1161/2000  Reconstruction Loss 0.042
# 1162/2000  Reconstruction Loss 0.044
# 1163/2000  Reconstruction Loss 0.045
# 1164/2000  Reconstruction Loss 0.046
# 1165/2000  Reconstruction Loss 0.050
# 1166/2000  Reconstruction Loss 0.046
# 1167/2000  Reconstruction Loss 0.046
# 1168/2000  Reconstruction Loss 0.049
# 1169/2000  Reconstruction Loss 0.049
# 1170/2000  Reconstruction Loss 0.047
# 1171/2000  Reconstruction Loss 0.047
# 1172/2000  Reconstruction Loss 0.049
# 1173/2000  Reconstruction Loss 0.050
# 1174/2000  Reconstruction Loss 0.048
# 1175/2000  Reconstruction Loss 0.049
# 1176/2000  Reconstruction Loss 0.051
# 1177/2000  Reconstruction Loss 0.047
# 1178/2000  Reconstruction Loss 0.045
# 1179/2000  Reconstruction Loss 0.047
# 1180/2000  Reconstruction Loss 0.044
# 1181/2000  Reconstruction Loss 0.045
# 1182/2000  Reconstruction Loss 0.043
# 1183/2000  Reconstruction Loss 0.043
# 1184/2000  Reconstruction Loss 0.042
# 1185/2000  Reconstruction Loss 0.043
# 1186/2000  Reconstruction Loss 0.041
# 1187/2000  Reconstruction Loss 0.040
# 1188/2000  Reconstruction Loss 0.040
# 1189/2000  Reconstruction Loss 0.039
# 1190/2000  Reconstruction Loss 0.040
# 1191/2000  Reconstruction Loss 0.038
# 1192/2000  Reconstruction Loss 0.038
# 1193/2000  Reconstruction Loss 0.038
# 1194/2000  Reconstruction Loss 0.038
# 1195/2000  Reconstruction Loss 0.038
# 1196/2000  Reconstruction Loss 0.038
# 1197/2000  Reconstruction Loss 0.038
# 1198/2000  Reconstruction Loss 0.038
# 1199/2000  Reconstruction Loss 0.040
# 1200/2000  Reconstruction Loss 0.039
# 1201/2000  Reconstruction Loss 0.041
# 1202/2000  Reconstruction Loss 0.045
# 1203/2000  Reconstruction Loss 0.052
# 1204/2000  Reconstruction Loss 0.061
# 1205/2000  Reconstruction Loss 0.068
# 1206/2000  Reconstruction Loss 0.062
# 1207/2000  Reconstruction Loss 0.061
# 1208/2000  Reconstruction Loss 0.050
# 1209/2000  Reconstruction Loss 0.057
# 1210/2000  Reconstruction Loss 0.054
# 1211/2000  Reconstruction Loss 0.048
# 1212/2000  Reconstruction Loss 0.051
# 1213/2000  Reconstruction Loss 0.048
# 1214/2000  Reconstruction Loss 0.047
# 1215/2000  Reconstruction Loss 0.044
# 1216/2000  Reconstruction Loss 0.045
# 1217/2000  Reconstruction Loss 0.044
# 1218/2000  Reconstruction Loss 0.041
# 1219/2000  Reconstruction Loss 0.042
# 1220/2000  Reconstruction Loss 0.040
# 1221/2000  Reconstruction Loss 0.042
# 1222/2000  Reconstruction Loss 0.038
# 1223/2000  Reconstruction Loss 0.040
# 1224/2000  Reconstruction Loss 0.038
# 1225/2000  Reconstruction Loss 0.039
# 1226/2000  Reconstruction Loss 0.038
# 1227/2000  Reconstruction Loss 0.037
# 1228/2000  Reconstruction Loss 0.037
# 1229/2000  Reconstruction Loss 0.037
# 1230/2000  Reconstruction Loss 0.037
# 1231/2000  Reconstruction Loss 0.036
# 1232/2000  Reconstruction Loss 0.036
# 1233/2000  Reconstruction Loss 0.035
# 1234/2000  Reconstruction Loss 0.035
# 1235/2000  Reconstruction Loss 0.035
# 1236/2000  Reconstruction Loss 0.035
# 1237/2000  Reconstruction Loss 0.035
# 1238/2000  Reconstruction Loss 0.034
# 1239/2000  Reconstruction Loss 0.034
# 1240/2000  Reconstruction Loss 0.034
# 1241/2000  Reconstruction Loss 0.034
# 1242/2000  Reconstruction Loss 0.034
# 1243/2000  Reconstruction Loss 0.034
# 1244/2000  Reconstruction Loss 0.034
# 1245/2000  Reconstruction Loss 0.035
# 1246/2000  Reconstruction Loss 0.036
# 1247/2000  Reconstruction Loss 0.040
# 1248/2000  Reconstruction Loss 0.045
# 1249/2000  Reconstruction Loss 0.057
# 1250/2000  Reconstruction Loss 0.045
# 1251/2000  Reconstruction Loss 0.044
# 1252/2000  Reconstruction Loss 0.047
# 1253/2000  Reconstruction Loss 0.042
# 1254/2000  Reconstruction Loss 0.045
# 1255/2000  Reconstruction Loss 0.049
# 1256/2000  Reconstruction Loss 0.048
# 1257/2000  Reconstruction Loss 0.047
# 1258/2000  Reconstruction Loss 0.046
# 1259/2000  Reconstruction Loss 0.045
# 1260/2000  Reconstruction Loss 0.043
# 1261/2000  Reconstruction Loss 0.044
# 1262/2000  Reconstruction Loss 0.040
# 1263/2000  Reconstruction Loss 0.041
# 1264/2000  Reconstruction Loss 0.039
# 1265/2000  Reconstruction Loss 0.039
# 1266/2000  Reconstruction Loss 0.039
# 1267/2000  Reconstruction Loss 0.037
# 1268/2000  Reconstruction Loss 0.037
# 1269/2000  Reconstruction Loss 0.037
# 1270/2000  Reconstruction Loss 0.037
# 1271/2000  Reconstruction Loss 0.036
# 1272/2000  Reconstruction Loss 0.035
# 1273/2000  Reconstruction Loss 0.035
# 1274/2000  Reconstruction Loss 0.034
# 1275/2000  Reconstruction Loss 0.034
# 1276/2000  Reconstruction Loss 0.034
# 1277/2000  Reconstruction Loss 0.034
# 1278/2000  Reconstruction Loss 0.033
# 1279/2000  Reconstruction Loss 0.033
# 1280/2000  Reconstruction Loss 0.033
# 1281/2000  Reconstruction Loss 0.033
# 1282/2000  Reconstruction Loss 0.032
# 1283/2000  Reconstruction Loss 0.032
# 1284/2000  Reconstruction Loss 0.032
# 1285/2000  Reconstruction Loss 0.032
# 1286/2000  Reconstruction Loss 0.032
# 1287/2000  Reconstruction Loss 0.032
# 1288/2000  Reconstruction Loss 0.033
# 1289/2000  Reconstruction Loss 0.033
# 1290/2000  Reconstruction Loss 0.034
# 1291/2000  Reconstruction Loss 0.034
# 1292/2000  Reconstruction Loss 0.037
# 1293/2000  Reconstruction Loss 0.043
# 1294/2000  Reconstruction Loss 0.053
# 1295/2000  Reconstruction Loss 0.056
# 1296/2000  Reconstruction Loss 0.048
# 1297/2000  Reconstruction Loss 0.038
# 1298/2000  Reconstruction Loss 0.037
# 1299/2000  Reconstruction Loss 0.044
# 1300/2000  Reconstruction Loss 0.043
# 1301/2000  Reconstruction Loss 0.037
# 1302/2000  Reconstruction Loss 0.036
# 1303/2000  Reconstruction Loss 0.039
# 1304/2000  Reconstruction Loss 0.040
# 1305/2000  Reconstruction Loss 0.035
# 1306/2000  Reconstruction Loss 0.034
# 1307/2000  Reconstruction Loss 0.038
# 1308/2000  Reconstruction Loss 0.034
# 1309/2000  Reconstruction Loss 0.033
# 1310/2000  Reconstruction Loss 0.035
# 1311/2000  Reconstruction Loss 0.033
# 1312/2000  Reconstruction Loss 0.032
# 1313/2000  Reconstruction Loss 0.033
# 1314/2000  Reconstruction Loss 0.033
# 1315/2000  Reconstruction Loss 0.033
# 1316/2000  Reconstruction Loss 0.033
# 1317/2000  Reconstruction Loss 0.035
# 1318/2000  Reconstruction Loss 0.033
# 1319/2000  Reconstruction Loss 0.032
# 1320/2000  Reconstruction Loss 0.031
# 1321/2000  Reconstruction Loss 0.032
# 1322/2000  Reconstruction Loss 0.032
# 1323/2000  Reconstruction Loss 0.031
# 1324/2000  Reconstruction Loss 0.031
# 1325/2000  Reconstruction Loss 0.031
# 1326/2000  Reconstruction Loss 0.031
# ...
# 1569/2000  Reconstruction Loss 0.024
# 1570/2000  Reconstruction Loss 0.024
# 1571/2000  Reconstruction Loss 0.025
# 1572/2000  Reconstruction Loss 0.022
# 1573/2000  Reconstruction Loss 0.023
# 1574/2000  Reconstruction Loss 0.022
# 1575/2000  Reconstruction Loss 0.023
# 1576/2000  Reconstruction Loss 0.022
# 1577/2000  Reconstruction Loss 0.022
# 1578/2000  Reconstruction Loss 0.021
# 1579/2000  Reconstruction Loss 0.021
# 1580/2000  Reconstruction Loss 0.021
# 1581/2000  Reconstruction Loss 0.021
# 1582/2000  Reconstruction Loss 0.021
# 1583/2000  Reconstruction Loss 0.021
# 1584/2000  Reconstruction Loss 0.021
# 1585/2000  Reconstruction Loss 0.021
# 1586/2000  Reconstruction Loss 0.020
# 1587/2000  Reconstruction Loss 0.020
# 1588/2000  Reconstruction Loss 0.020
# 1589/2000  Reconstruction Loss 0.020
# 1590/2000  Reconstruction Loss 0.021
# 1591/2000  Reconstruction Loss 0.021
# 1592/2000  Reconstruction Loss 0.021
# 1593/2000  Reconstruction Loss 0.022
# 1594/2000  Reconstruction Loss 0.023
# 1595/2000  Reconstruction Loss 0.025
# 1596/2000  Reconstruction Loss 0.028
# 1597/2000  Reconstruction Loss 0.035
# 1598/2000  Reconstruction Loss 0.036
# 1599/2000  Reconstruction Loss 0.032
# 1600/2000  Reconstruction Loss 0.031
# 1601/2000  Reconstruction Loss 0.029
# 1602/2000  Reconstruction Loss 0.024
# 1603/2000  Reconstruction Loss 0.026
# 1604/2000  Reconstruction Loss 0.028
# 1605/2000  Reconstruction Loss 0.024
# 1606/2000  Reconstruction Loss 0.028
# 1607/2000  Reconstruction Loss 0.025
# 1608/2000  Reconstruction Loss 0.024
# 1609/2000  Reconstruction Loss 0.026
# 1610/2000  Reconstruction Loss 0.024
# 1611/2000  Reconstruction Loss 0.024
# 1612/2000  Reconstruction Loss 0.023
# 1613/2000  Reconstruction Loss 0.024
# 1614/2000  Reconstruction Loss 0.023
# 1615/2000  Reconstruction Loss 0.022
# 1616/2000  Reconstruction Loss 0.022
# 1617/2000  Reconstruction Loss 0.021
# 1618/2000  Reconstruction Loss 0.022
# 1619/2000  Reconstruction Loss 0.021
# 1620/2000  Reconstruction Loss 0.022
# 1621/2000  Reconstruction Loss 0.022
# 1622/2000  Reconstruction Loss 0.021
# 1623/2000  Reconstruction Loss 0.021
# 1624/2000  Reconstruction Loss 0.020
# 1625/2000  Reconstruction Loss 0.020
# 1626/2000  Reconstruction Loss 0.020
# 1627/2000  Reconstruction Loss 0.020
# 1628/2000  Reconstruction Loss 0.020
# 1629/2000  Reconstruction Loss 0.020
# 1630/2000  Reconstruction Loss 0.020
# 1631/2000  Reconstruction Loss 0.020
# 1632/2000  Reconstruction Loss 0.020
# 1633/2000  Reconstruction Loss 0.019
# 1634/2000  Reconstruction Loss 0.020
# 1635/2000  Reconstruction Loss 0.019
# 1636/2000  Reconstruction Loss 0.020
# 1637/2000  Reconstruction Loss 0.020
# 1638/2000  Reconstruction Loss 0.020
# 1639/2000  Reconstruction Loss 0.020
# 1640/2000  Reconstruction Loss 0.020
# 1641/2000  Reconstruction Loss 0.019
# 1642/2000  Reconstruction Loss 0.019
# 1643/2000  Reconstruction Loss 0.019
# 1644/2000  Reconstruction Loss 0.019
# 1645/2000  Reconstruction Loss 0.019
# 1646/2000  Reconstruction Loss 0.020
# 1647/2000  Reconstruction Loss 0.021
# 1648/2000  Reconstruction Loss 0.022
# 1649/2000  Reconstruction Loss 0.022
# 1650/2000  Reconstruction Loss 0.024
# 1651/2000  Reconstruction Loss 0.024
# 1652/2000  Reconstruction Loss 0.025
# 1653/2000  Reconstruction Loss 0.026
# 1654/2000  Reconstruction Loss 0.027
# 1655/2000  Reconstruction Loss 0.026
# 1656/2000  Reconstruction Loss 0.024
# 1657/2000  Reconstruction Loss 0.025
# 1658/2000  Reconstruction Loss 0.026
# 1659/2000  Reconstruction Loss 0.026
# 1660/2000  Reconstruction Loss 0.024
# 1661/2000  Reconstruction Loss 0.024
# 1662/2000  Reconstruction Loss 0.025
# 1663/2000  Reconstruction Loss 0.023
# 1664/2000  Reconstruction Loss 0.022
# 1665/2000  Reconstruction Loss 0.023
# 1666/2000  Reconstruction Loss 0.021
# 1667/2000  Reconstruction Loss 0.023
# 1668/2000  Reconstruction Loss 0.023
# 1669/2000  Reconstruction Loss 0.022
# 1670/2000  Reconstruction Loss 0.023
# 1671/2000  Reconstruction Loss 0.022
# 1672/2000  Reconstruction Loss 0.021
# 1673/2000  Reconstruction Loss 0.021
# 1674/2000  Reconstruction Loss 0.020
# 1675/2000  Reconstruction Loss 0.021
# 1676/2000  Reconstruction Loss 0.021
# 1677/2000  Reconstruction Loss 0.020
# 1678/2000  Reconstruction Loss 0.020
# 1679/2000  Reconstruction Loss 0.019
# 1680/2000  Reconstruction Loss 0.020
# 1681/2000  Reconstruction Loss 0.019
# 1682/2000  Reconstruction Loss 0.019
# 1683/2000  Reconstruction Loss 0.019
# 1684/2000  Reconstruction Loss 0.019
# 1685/2000  Reconstruction Loss 0.019
# 1686/2000  Reconstruction Loss 0.018
# 1687/2000  Reconstruction Loss 0.018
# 1688/2000  Reconstruction Loss 0.018
# 1689/2000  Reconstruction Loss 0.018
# 1690/2000  Reconstruction Loss 0.018
# 1691/2000  Reconstruction Loss 0.018
# 1692/2000  Reconstruction Loss 0.018
# 1693/2000  Reconstruction Loss 0.018
# 1694/2000  Reconstruction Loss 0.018
# 1695/2000  Reconstruction Loss 0.019
# 1696/2000  Reconstruction Loss 0.020
# 1697/2000  Reconstruction Loss 0.023
# 1698/2000  Reconstruction Loss 0.026
# 1699/2000  Reconstruction Loss 0.030
# 1700/2000  Reconstruction Loss 0.032
# 1701/2000  Reconstruction Loss 0.031
# 1702/2000  Reconstruction Loss 0.025
# 1703/2000  Reconstruction Loss 0.022
# 1704/2000  Reconstruction Loss 0.024
# 1705/2000  Reconstruction Loss 0.025
# 1706/2000  Reconstruction Loss 0.025
# 1707/2000  Reconstruction Loss 0.022
# 1708/2000  Reconstruction Loss 0.021
# 1709/2000  Reconstruction Loss 0.021
# 1710/2000  Reconstruction Loss 0.021
# 1711/2000  Reconstruction Loss 0.022
# 1712/2000  Reconstruction Loss 0.019
# 1713/2000  Reconstruction Loss 0.019
# 1714/2000  Reconstruction Loss 0.020
# 1715/2000  Reconstruction Loss 0.020
# 1716/2000  Reconstruction Loss 0.018
# 1717/2000  Reconstruction Loss 0.018
# 1718/2000  Reconstruction Loss 0.019
# 1719/2000  Reconstruction Loss 0.018
# 1720/2000  Reconstruction Loss 0.018
# 1721/2000  Reconstruction Loss 0.018
# 1722/2000  Reconstruction Loss 0.018
# 1723/2000  Reconstruction Loss 0.018
# 1724/2000  Reconstruction Loss 0.017
# 1725/2000  Reconstruction Loss 0.017
# 1726/2000  Reconstruction Loss 0.017
# 1727/2000  Reconstruction Loss 0.017
# 1728/2000  Reconstruction Loss 0.017
# 1729/2000  Reconstruction Loss 0.017
# 1730/2000  Reconstruction Loss 0.017
# 1731/2000  Reconstruction Loss 0.018
# 1732/2000  Reconstruction Loss 0.019
# 1733/2000  Reconstruction Loss 0.020
# 1734/2000  Reconstruction Loss 0.020
# 1735/2000  Reconstruction Loss 0.020
# 1736/2000  Reconstruction Loss 0.019
# 1737/2000  Reconstruction Loss 0.020
# 1738/2000  Reconstruction Loss 0.019
# 1739/2000  Reconstruction Loss 0.018
# 1740/2000  Reconstruction Loss 0.017
# 1741/2000  Reconstruction Loss 0.018
# 1742/2000  Reconstruction Loss 0.019
# 1743/2000  Reconstruction Loss 0.018
# 1744/2000  Reconstruction Loss 0.018
# 1745/2000  Reconstruction Loss 0.017
# 1746/2000  Reconstruction Loss 0.017
# 1747/2000  Reconstruction Loss 0.017
# 1748/2000  Reconstruction Loss 0.017
# 1749/2000  Reconstruction Loss 0.017
# 1750/2000  Reconstruction Loss 0.017
# 1751/2000  Reconstruction Loss 0.017
# 1752/2000  Reconstruction Loss 0.017
# 1753/2000  Reconstruction Loss 0.018
# 1754/2000  Reconstruction Loss 0.020
# 1755/2000  Reconstruction Loss 0.022
# 1756/2000  Reconstruction Loss 0.027
# 1757/2000  Reconstruction Loss 0.030
# 1758/2000  Reconstruction Loss 0.031
# 1759/2000  Reconstruction Loss 0.028
# 1760/2000  Reconstruction Loss 0.020
# 1761/2000  Reconstruction Loss 0.020
# 1762/2000  Reconstruction Loss 0.025
# 1763/2000  Reconstruction Loss 0.026
# 1764/2000  Reconstruction Loss 0.022
# 1765/2000  Reconstruction Loss 0.024
# 1766/2000  Reconstruction Loss 0.022
# 1767/2000  Reconstruction Loss 0.021
# 1768/2000  Reconstruction Loss 0.022
# 1769/2000  Reconstruction Loss 0.021
# 1770/2000  Reconstruction Loss 0.020
# 1771/2000  Reconstruction Loss 0.020
# 1772/2000  Reconstruction Loss 0.019
# 1773/2000  Reconstruction Loss 0.020
# 1774/2000  Reconstruction Loss 0.020
# 1775/2000  Reconstruction Loss 0.018
# 1776/2000  Reconstruction Loss 0.018
# 1777/2000  Reconstruction Loss 0.018
# 1778/2000  Reconstruction Loss 0.018
# 1779/2000  Reconstruction Loss 0.018
# 1780/2000  Reconstruction Loss 0.017
# 1781/2000  Reconstruction Loss 0.017
# 1782/2000  Reconstruction Loss 0.017
# 1783/2000  Reconstruction Loss 0.017
# 1784/2000  Reconstruction Loss 0.016
# 1785/2000  Reconstruction Loss 0.016
# 1786/2000  Reconstruction Loss 0.016
# 1787/2000  Reconstruction Loss 0.016
# 1788/2000  Reconstruction Loss 0.016
# 1789/2000  Reconstruction Loss 0.016
# 1790/2000  Reconstruction Loss 0.016
# 1791/2000  Reconstruction Loss 0.016
# 1792/2000  Reconstruction Loss 0.016
# 1793/2000  Reconstruction Loss 0.016
# 1794/2000  Reconstruction Loss 0.016
# 1795/2000  Reconstruction Loss 0.017
# 1796/2000  Reconstruction Loss 0.017
# 1797/2000  Reconstruction Loss 0.017
# 1798/2000  Reconstruction Loss 0.017
# 1799/2000  Reconstruction Loss 0.018
# 1800/2000  Reconstruction Loss 0.018
# 1801/2000  Reconstruction Loss 0.018
# 1802/2000  Reconstruction Loss 0.017
# 1803/2000  Reconstruction Loss 0.016
# 1804/2000  Reconstruction Loss 0.016
# 1805/2000  Reconstruction Loss 0.016
# 1806/2000  Reconstruction Loss 0.016
# 1807/2000  Reconstruction Loss 0.017
# 1808/2000  Reconstruction Loss 0.018
# 1809/2000  Reconstruction Loss 0.018
# 1810/2000  Reconstruction Loss 0.020
# 1811/2000  Reconstruction Loss 0.018
# 1812/2000  Reconstruction Loss 0.019
# 1813/2000  Reconstruction Loss 0.019
# 1814/2000  Reconstruction Loss 0.019
# 1815/2000  Reconstruction Loss 0.020
# 1816/2000  Reconstruction Loss 0.018
# 1817/2000  Reconstruction Loss 0.017
# 1818/2000  Reconstruction Loss 0.019
# 1819/2000  Reconstruction Loss 0.018
# 1820/2000  Reconstruction Loss 0.017
# 1821/2000  Reconstruction Loss 0.016
# 1822/2000  Reconstruction Loss 0.017
# 1823/2000  Reconstruction Loss 0.018
# 1824/2000  Reconstruction Loss 0.016
# 1825/2000  Reconstruction Loss 0.017
# 1826/2000  Reconstruction Loss 0.018
# 1827/2000  Reconstruction Loss 0.015
# 1828/2000  Reconstruction Loss 0.016
# 1829/2000  Reconstruction Loss 0.017
# 1830/2000  Reconstruction Loss 0.016
# 1831/2000  Reconstruction Loss 0.016
# 1832/2000  Reconstruction Loss 0.017
# 1833/2000  Reconstruction Loss 0.015
# 1834/2000  Reconstruction Loss 0.016
# 1835/2000  Reconstruction Loss 0.016
# 1836/2000  Reconstruction Loss 0.015
# 1837/2000  Reconstruction Loss 0.015
# 1838/2000  Reconstruction Loss 0.015
# 1839/2000  Reconstruction Loss 0.015
# 1840/2000  Reconstruction Loss 0.016
# 1841/2000  Reconstruction Loss 0.016
# 1842/2000  Reconstruction Loss 0.015
# 1843/2000  Reconstruction Loss 0.016
# 1844/2000  Reconstruction Loss 0.016
# 1845/2000  Reconstruction Loss 0.016
# 1846/2000  Reconstruction Loss 0.017
# 1847/2000  Reconstruction Loss 0.018
# 1848/2000  Reconstruction Loss 0.021
# 1849/2000  Reconstruction Loss 0.028
# 1850/2000  Reconstruction Loss 0.038
# 1851/2000  Reconstruction Loss 0.045
# 1852/2000  Reconstruction Loss 0.035
# 1853/2000  Reconstruction Loss 0.024
# 1854/2000  Reconstruction Loss 0.027
# 1855/2000  Reconstruction Loss 0.027
# 1856/2000  Reconstruction Loss 0.027
# 1857/2000  Reconstruction Loss 0.034
# 1858/2000  Reconstruction Loss 0.034
# 1859/2000  Reconstruction Loss 0.033
# 1860/2000  Reconstruction Loss 0.033
# 1861/2000  Reconstruction Loss 0.031
# 1862/2000  Reconstruction Loss 0.027
# 1863/2000  Reconstruction Loss 0.029
# 1864/2000  Reconstruction Loss 0.026
# 1865/2000  Reconstruction Loss 0.025
# 1866/2000  Reconstruction Loss 0.025
# 1867/2000  Reconstruction Loss 0.024
# 1868/2000  Reconstruction Loss 0.022
# 1869/2000  Reconstruction Loss 0.022
# 1870/2000  Reconstruction Loss 0.021
# 1871/2000  Reconstruction Loss 0.020
# 1872/2000  Reconstruction Loss 0.020
# 1873/2000  Reconstruction Loss 0.019
# 1874/2000  Reconstruction Loss 0.019
# 1875/2000  Reconstruction Loss 0.019
# 1876/2000  Reconstruction Loss 0.018
# 1877/2000  Reconstruction Loss 0.017
# 1878/2000  Reconstruction Loss 0.017
# 1879/2000  Reconstruction Loss 0.017
# 1880/2000  Reconstruction Loss 0.017
# 1881/2000  Reconstruction Loss 0.016
# 1882/2000  Reconstruction Loss 0.016
# 1883/2000  Reconstruction Loss 0.016
# 1884/2000  Reconstruction Loss 0.015
# 1885/2000  Reconstruction Loss 0.015
# 1886/2000  Reconstruction Loss 0.015
# 1887/2000  Reconstruction Loss 0.015
# 1888/2000  Reconstruction Loss 0.015
# 1889/2000  Reconstruction Loss 0.015
# 1890/2000  Reconstruction Loss 0.015
# 1891/2000  Reconstruction Loss 0.015
# 1892/2000  Reconstruction Loss 0.014
# 1893/2000  Reconstruction Loss 0.014
# 1894/2000  Reconstruction Loss 0.014
# 1895/2000  Reconstruction Loss 0.014
# 1896/2000  Reconstruction Loss 0.014
# 1897/2000  Reconstruction Loss 0.014
# 1898/2000  Reconstruction Loss 0.014
# 1899/2000  Reconstruction Loss 0.014
# 1900/2000  Reconstruction Loss 0.014
# 1901/2000  Reconstruction Loss 0.014
# 1902/2000  Reconstruction Loss 0.014
# 1903/2000  Reconstruction Loss 0.014
# 1904/2000  Reconstruction Loss 0.014
# 1905/2000  Reconstruction Loss 0.014
# 1906/2000  Reconstruction Loss 0.014
# 1907/2000  Reconstruction Loss 0.014
# 1908/2000  Reconstruction Loss 0.014
# 1909/2000  Reconstruction Loss 0.014
# 1910/2000  Reconstruction Loss 0.015
# 1911/2000  Reconstruction Loss 0.016
# 1912/2000  Reconstruction Loss 0.018
# 1913/2000  Reconstruction Loss 0.019
# 1914/2000  Reconstruction Loss 0.019
# 1915/2000  Reconstruction Loss 0.016
# 1916/2000  Reconstruction Loss 0.014
# 1917/2000  Reconstruction Loss 0.015
# 1918/2000  Reconstruction Loss 0.017
# 1919/2000  Reconstruction Loss 0.017
# 1920/2000  Reconstruction Loss 0.015
# 1921/2000  Reconstruction Loss 0.014
# 1922/2000  Reconstruction Loss 0.016
# 1923/2000  Reconstruction Loss 0.016
# 1924/2000  Reconstruction Loss 0.014
# 1925/2000  Reconstruction Loss 0.014
# 1926/2000  Reconstruction Loss 0.015
# 1927/2000  Reconstruction Loss 0.015
# 1928/2000  Reconstruction Loss 0.014
# 1929/2000  Reconstruction Loss 0.013
# 1930/2000  Reconstruction Loss 0.014
# 1931/2000  Reconstruction Loss 0.014
# 1932/2000  Reconstruction Loss 0.013
# 1933/2000  Reconstruction Loss 0.013
# 1934/2000  Reconstruction Loss 0.014
# 1935/2000  Reconstruction Loss 0.014
# 1936/2000  Reconstruction Loss 0.013
# 1937/2000  Reconstruction Loss 0.013
# 1938/2000  Reconstruction Loss 0.013
# 1939/2000  Reconstruction Loss 0.014
# 1940/2000  Reconstruction Loss 0.014
# 1941/2000  Reconstruction Loss 0.014
# 1942/2000  Reconstruction Loss 0.015
# 1943/2000  Reconstruction Loss 0.016
# 1944/2000  Reconstruction Loss 0.018
# 1945/2000  Reconstruction Loss 0.019
# 1946/2000  Reconstruction Loss 0.019
# 1947/2000  Reconstruction Loss 0.018
# 1948/2000  Reconstruction Loss 0.017
# 1949/2000  Reconstruction Loss 0.015
# 1950/2000  Reconstruction Loss 0.015
# 1951/2000  Reconstruction Loss 0.016
# 1952/2000  Reconstruction Loss 0.017
# 1953/2000  Reconstruction Loss 0.016
# 1954/2000  Reconstruction Loss 0.015
# 1955/2000  Reconstruction Loss 0.014
# 1956/2000  Reconstruction Loss 0.015
# 1957/2000  Reconstruction Loss 0.016
# 1958/2000  Reconstruction Loss 0.015
# 1959/2000  Reconstruction Loss 0.014
# 1960/2000  Reconstruction Loss 0.015
# 1961/2000  Reconstruction Loss 0.014
# 1962/2000  Reconstruction Loss 0.013
# 1963/2000  Reconstruction Loss 0.014
# 1964/2000  Reconstruction Loss 0.014
# 1965/2000  Reconstruction Loss 0.014
# 1966/2000  Reconstruction Loss 0.013
# 1967/2000  Reconstruction Loss 0.014
# 1968/2000  Reconstruction Loss 0.013
# 1969/2000  Reconstruction Loss 0.013
# 1970/2000  Reconstruction Loss 0.013
# 1971/2000  Reconstruction Loss 0.013
# 1972/2000  Reconstruction Loss 0.013
# 1973/2000  Reconstruction Loss 0.013
# 1974/2000  Reconstruction Loss 0.013
# 1975/2000  Reconstruction Loss 0.014
# 1976/2000  Reconstruction Loss 0.014
# 1977/2000  Reconstruction Loss 0.016
# 1978/2000  Reconstruction Loss 0.018
# 1979/2000  Reconstruction Loss 0.020
# 1980/2000  Reconstruction Loss 0.023
# 1981/2000  Reconstruction Loss 0.023
# 1982/2000  Reconstruction Loss 0.022
# 1983/2000  Reconstruction Loss 0.019
# 1984/2000  Reconstruction Loss 0.019
# 1985/2000  Reconstruction Loss 0.021
# 1986/2000  Reconstruction Loss 0.020
# 1987/2000  Reconstruction Loss 0.019
# 1988/2000  Reconstruction Loss 0.018
# 1989/2000  Reconstruction Loss 0.017
# 1990/2000  Reconstruction Loss 0.018
# 1991/2000  Reconstruction Loss 0.016
# 1992/2000  Reconstruction Loss 0.017
# 1993/2000  Reconstruction Loss 0.018
# 1994/2000  Reconstruction Loss 0.015
# 1995/2000  Reconstruction Loss 0.016
# 1996/2000  Reconstruction Loss 0.015
# 1997/2000  Reconstruction Loss 0.015
# 1998/2000  Reconstruction Loss 0.015
# 1999/2000  Reconstruction Loss 0.014
# 2000/2000  Reconstruction Loss 0.015

# %%
import matplotlib.pyplot as plt 
import numpy as np
import nibabel as ni 
import torch

def display_image(x, y):
    assert x.shape == y.shape
    if x.dim() == 5:
        x = torch.reshape(x, (x.shape[0], 64, 64, 8)).cpu().detach().numpy()
        y = torch.reshape(y, (y.shape[0], 64, 64, 8)).cpu().detach().numpy()
        for i in range(len(x)):
            rows = 2
            columns = 1
            fig=plt.figure()
            for idx in range(rows*columns):
                fig.add_subplot(rows, columns, idx+1)
                if idx < columns:
                    plt.imshow(x[i, :, :, 4], cmap="gray", origin="lower")
                else:
                    plt.imshow(y[i, :, :, 4], cmap="gray", origin="lower")
            plt.show()

# %%
import nibabel as ni
import numpy as np
import os, glob
import torch 
import csv
from tqdm import tqdm
import matplotlib.pyplot as plt 

batch_size = 1
path_data = "../ircad-dataset/test"
path_model = "./checkpoint/model_epoch_2000.pt"

log = print
np.random.seed(10)
torch.manual_seed(10)

criterion_dis = nn.MSELoss()

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(" GPU is activated" if device else " CPU is activated")
no_images = len(glob.glob(path_data + "/*.nii"))
print("Number of MRI images: ", no_images)

model = torch.load(path_model)
model.to(device)
total_loss = 0
    
# interfere phrase
model.eval()
with torch.no_grad():
    for batch_images in load_mri_images(path_data, batch_size):
        batch_images = batch_images.to(device)
        y = model(batch_images[:, :, :, :, 4])

        # Measure loss
        loss = criterion(batch_images, y)

        total_loss += loss.item() * batch_images.shape[0]

        # display
        display_image(batch_images, y)

print("Loss: {:.4f}".format(total_loss/ no_images))
# Out:
#  GPU is activated
# Number of MRI images:  6
# Loss: 0.4442
