# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import init
import math 


class ResNet(nn.Module):
    def __init__(self, net):
        super().__init__()
        self.net = net

    def forward(self, x):
        return x + self.net(x)


class Conv2DBlock(nn.Module):
    def __init__(self, in_ch, out_ch, k, s=1, p=1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, k, s, p),
            nn.BatchNorm2d(out_ch),
            nn.ELU(),
        )

    def forward(self, x):
        return self.net(x)


class RepresentationNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(  # (1, 64, 64)
            Conv2DBlock(1, 128, 4, 2),  # (128, 32, 32)
            ResNet(Conv2DBlock(128, 128, 3)),
            Conv2DBlock(128, 256, 4, 2),  # (256, 16, 16)
            ResNet(Conv2DBlock(256, 256, 3)),
            Conv2DBlock(256, 512, 4, 2),  # (512, 8, 8)
            ResNet(Conv2DBlock(512, 512, 3)),
        )

    def forward(self, x):
        return self.net(x)


class TransformModule(nn.Module):
    def __init__(self):
        super().__init__()
        self.net1 = nn.Sequential(
            nn.Conv2d(512, 512, 1, 1, 0),  # (512, 8, 8)
            nn.ELU(),
        )
        self.net2 = nn.Sequential(
            nn.ConvTranspose3d(512, 512, 1, 1, 0),  # (512, 8, 8, 1)
            nn.ELU(),
        )

    def forward(self, x):
        x = self.net1(x)
        x = x.view(-1, 512, 8, 8, 1)
        x = self.net2(x)
        return x


class Deconv3DBlock(nn.Module):
    def __init__(self, in_ch, out_ch, k, s=1, p=1):
        super().__init__()
        self.net = nn.Sequential(
            nn.ConvTranspose3d(in_ch, out_ch, k, s, p),
            nn.BatchNorm3d(out_ch),
            nn.ELU(),
        )

    def forward(self, x):
        return self.net(x)


class GenerationNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(  # (512, 8, 8, 1)
            Deconv3DBlock(512, 256, 4, 2),  # (256, 16, 16, 2)
            Deconv3DBlock(256, 256, 3),
            Deconv3DBlock(256, 128, 4, 2),  # (128, 32, 32, 4)
            Deconv3DBlock(128, 128, 3),
            Deconv3DBlock(128, 64, 4, 2),  # (64, 64, 64, 8)
            Deconv3DBlock(64, 64, 3),
            nn.Conv3d(64, 1, 1, 1, 0),  # (1, 64, 64, 8)
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.net(x)


class ReconstructionNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            RepresentationNetwork(),
            TransformModule(),
            GenerationNetwork(),
        )

    def forward(self, x):
        return self.net(x)

# %%
import torch
import numpy as np
import nibabel as ni
import os, shutil
import time
import random
import pandas as pd 

def split_train_test(dir, ratio_test=0.15):
    if os.path.exists(os.path.join(dir, "train")):
        return
    os.mkdir(os.path.join(dir, "train"))
    if not os.path.exists(os.path.join(dir, "test")):
        return
    os.mkdir(os.path.join(dir, "test"))
    
    images_list = [i for i in os.listdir(dir) if i.endswith(".nii")]

    random.shuffle(images_list)
    threshold = int(len(images_list)*ratio_test)
    train_list = images_list[:-threshold]
    test_list = images_list[-threshold:]

    for i in train_list:
        shutil.move(os.path.join(dir, i), os.path.join(dir, "train", i))
    for i in test_list:
        shutil.move(os.path.join(dir, i), os.path.join(dir, "test", i))

def save_data_to_csv(dir, z):
    pd.DataFrame(z).to_csv(dir, header=None, index=False)

def load_mri_images(path, batch_size):
    filenames = [i for i in os.listdir(path) if i.endswith("orig.nii")]
    random.shuffle(filenames)
    n = 0
    pool = nn.AvgPool3d(8)
    while n < len(filenames):
        batch_image = []
        for i in range(n, n + batch_size):
            if i >= len(filenames):
                ##n = i
                break
            image = ni.load(os.path.join(path, filenames[i]))
            image = np.array(image.dataobj)
            depth = image.shape[2]
            image = torch.Tensor(image)[:, :, depth//2-32:depth//2+32]  # (512, 512, 64)
            image = (image - image.min()) / (image.max() - image.min())
            image = torch.reshape(image, (1, 1, 512, 512, 64))
            image = pool(image)  # (64, 64, 8)
            batch_image.append(image)
        n += batch_size
        batch_image = torch.cat(batch_image, axis=0)
        yield batch_image

# %%
start = time.time()
for i in load_mri_images("../ircad-dataset/train/", 2):
    print(time.time()-start)
    start = time.time()
    print(i.shape)

split_train_test("../ircad-dataset")
# Out:
# 0.5349681377410889
# torch.Size([2, 1, 64, 64, 8])
# 0.5376121997833252
# torch.Size([2, 1, 64, 64, 8])
# 0.4889099597930908
# torch.Size([2, 1, 64, 64, 8])
# 0.5046861171722412
# torch.Size([2, 1, 64, 64, 8])
# 0.5307953357696533
# torch.Size([2, 1, 64, 64, 8])
# 0.5159714221954346
# torch.Size([2, 1, 64, 64, 8])
# 0.5394420623779297
# torch.Size([2, 1, 64, 64, 8])
# 0.5094788074493408
# torch.Size([2, 1, 64, 64, 8])

# %%
"""
Author: Duy-Phuong Dao
Email: phuongdd.1997@gmail.com (or duyphuongcri@gmail.com)
"""

import nibabel as ni
import numpy as np
import os, glob
import torch
import csv
import random
from tqdm import tqdm

##---------Settings--------------------------
batch_size = 64
lrate = 0.01
epochs = 2000
weight_decay = 5e-7
##############
path_data = "../ircad-dataset/train"
path2save = "./checkpoint/3drec-cont_{}.pt"
dir_info = './infor'       
f = open(os.path.join(dir_info,'3drec-cont_t1.csv'),'w',newline='')


####################
log = print
np.random.seed(10)
torch.manual_seed(10)
###################
criterion = nn.MSELoss()

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(" GPU is activated" if device else " CPU is activated")
no_images = len(glob.glob(path_data + "/*.nii"))
print("Number of MRI images: ", no_images)

model = ReconstructionNetwork()
model.to(device)
#log(vae_model)
optimizer = torch.optim.Adam(model.parameters(), lr=lrate, weight_decay=weight_decay)
for epoch in range(epochs):
    loss_epoch = 0
    
    # training phrase
    model.train()
    for batch_images in load_mri_images(path_data, batch_size):
        optimizer.zero_grad()
        batch_images = batch_images.to(device)
        y = model(batch_images[:, :, :, :, 4])
        
        # Measure loss
        loss = criterion(batch_images, y)

        # Optimize
        loss.backward()
        optimizer.step()
        
        loss_epoch += loss.item() * batch_images.shape[0]

    # save model
    log_info = (epoch + 1, epochs, loss_epoch/no_images)
    log('%d/%d  Reconstruction Loss %.3f'% log_info)
    if (epoch+1) % 100 == 0:
        torch.save(model, path2save.format(epoch+1))  

    # write csv
    writer = csv.writer(f)
    writer.writerow([epoch + 1, '{:04f}'.format(loss_epoch/no_images)])
f.close()
# Out:
#  GPU is activated
# Number of MRI images:  34
# 1/2000  Reconstruction Loss 0.055
# 2/2000  Reconstruction Loss 0.037
# 3/2000  Reconstruction Loss 0.049
# 4/2000  Reconstruction Loss 0.036
# 5/2000  Reconstruction Loss 0.029
# 6/2000  Reconstruction Loss 0.026
# 7/2000  Reconstruction Loss 0.024
# 8/2000  Reconstruction Loss 0.021
# 9/2000  Reconstruction Loss 0.019
# 10/2000  Reconstruction Loss 0.019
# 11/2000  Reconstruction Loss 0.017
# 12/2000  Reconstruction Loss 0.015
# 13/2000  Reconstruction Loss 0.013
# 14/2000  Reconstruction Loss 0.013
# 15/2000  Reconstruction Loss 0.013
# 16/2000  Reconstruction Loss 0.012
# 17/2000  Reconstruction Loss 0.011
# 18/2000  Reconstruction Loss 0.010
# 19/2000  Reconstruction Loss 0.010
# 20/2000  Reconstruction Loss 0.010
# 21/2000  Reconstruction Loss 0.010
# 22/2000  Reconstruction Loss 0.010
# 23/2000  Reconstruction Loss 0.010
# 24/2000  Reconstruction Loss 0.009
# 25/2000  Reconstruction Loss 0.009
# 26/2000  Reconstruction Loss 0.009
# 27/2000  Reconstruction Loss 0.009
# 28/2000  Reconstruction Loss 0.009
# 29/2000  Reconstruction Loss 0.008
# 30/2000  Reconstruction Loss 0.008
# 31/2000  Reconstruction Loss 0.008
# 32/2000  Reconstruction Loss 0.008
# 33/2000  Reconstruction Loss 0.008
# 34/2000  Reconstruction Loss 0.007
# 35/2000  Reconstruction Loss 0.007
# 36/2000  Reconstruction Loss 0.007
# 37/2000  Reconstruction Loss 0.007
# 38/2000  Reconstruction Loss 0.007
# 39/2000  Reconstruction Loss 0.006
# 40/2000  Reconstruction Loss 0.006
# 41/2000  Reconstruction Loss 0.006
# 42/2000  Reconstruction Loss 0.006
# 43/2000  Reconstruction Loss 0.006
# 44/2000  Reconstruction Loss 0.006
# 45/2000  Reconstruction Loss 0.006
# 46/2000  Reconstruction Loss 0.006
# 47/2000  Reconstruction Loss 0.006
# 48/2000  Reconstruction Loss 0.006
# 49/2000  Reconstruction Loss 0.005
# 50/2000  Reconstruction Loss 0.005
# 51/2000  Reconstruction Loss 0.005
# 52/2000  Reconstruction Loss 0.005
# 53/2000  Reconstruction Loss 0.005
# 54/2000  Reconstruction Loss 0.005
# 55/2000  Reconstruction Loss 0.005
# 56/2000  Reconstruction Loss 0.005
# 57/2000  Reconstruction Loss 0.005
# 58/2000  Reconstruction Loss 0.005
# 59/2000  Reconstruction Loss 0.005
# 60/2000  Reconstruction Loss 0.005
# 61/2000  Reconstruction Loss 0.005
# 62/2000  Reconstruction Loss 0.005
# 63/2000  Reconstruction Loss 0.005
# 64/2000  Reconstruction Loss 0.005
# 65/2000  Reconstruction Loss 0.005
# 66/2000  Reconstruction Loss 0.005
# 67/2000  Reconstruction Loss 0.005
# 68/2000  Reconstruction Loss 0.005
# 69/2000  Reconstruction Loss 0.005
# 70/2000  Reconstruction Loss 0.005
# 71/2000  Reconstruction Loss 0.005
# 72/2000  Reconstruction Loss 0.005
# 73/2000  Reconstruction Loss 0.005
# 74/2000  Reconstruction Loss 0.004
# 75/2000  Reconstruction Loss 0.004
# 76/2000  Reconstruction Loss 0.004
# 77/2000  Reconstruction Loss 0.004
# 78/2000  Reconstruction Loss 0.004
# 79/2000  Reconstruction Loss 0.004
# 80/2000  Reconstruction Loss 0.004
# 81/2000  Reconstruction Loss 0.004
# 82/2000  Reconstruction Loss 0.004
# 83/2000  Reconstruction Loss 0.004
# 84/2000  Reconstruction Loss 0.004
# 85/2000  Reconstruction Loss 0.004
# 86/2000  Reconstruction Loss 0.004
# 87/2000  Reconstruction Loss 0.004
# 88/2000  Reconstruction Loss 0.004
# 89/2000  Reconstruction Loss 0.004
# 90/2000  Reconstruction Loss 0.004
# 91/2000  Reconstruction Loss 0.004
# 92/2000  Reconstruction Loss 0.004
# 93/2000  Reconstruction Loss 0.004
# 94/2000  Reconstruction Loss 0.004
# 95/2000  Reconstruction Loss 0.004
# 96/2000  Reconstruction Loss 0.004
# 97/2000  Reconstruction Loss 0.004
# 98/2000  Reconstruction Loss 0.004
# 99/2000  Reconstruction Loss 0.004
# 100/2000  Reconstruction Loss 0.004
# 101/2000  Reconstruction Loss 0.004
# 102/2000  Reconstruction Loss 0.004
# 103/2000  Reconstruction Loss 0.004
# 104/2000  Reconstruction Loss 0.004
# 105/2000  Reconstruction Loss 0.004
# 106/2000  Reconstruction Loss 0.004
# 107/2000  Reconstruction Loss 0.004
# 108/2000  Reconstruction Loss 0.004
# 109/2000  Reconstruction Loss 0.004
# 110/2000  Reconstruction Loss 0.004
# 111/2000  Reconstruction Loss 0.004
# 112/2000  Reconstruction Loss 0.004
# 113/2000  Reconstruction Loss 0.004
# 114/2000  Reconstruction Loss 0.004
# 115/2000  Reconstruction Loss 0.004
# 116/2000  Reconstruction Loss 0.004
# 117/2000  Reconstruction Loss 0.004
# 118/2000  Reconstruction Loss 0.004
# 119/2000  Reconstruction Loss 0.004
# 120/2000  Reconstruction Loss 0.004
# 121/2000  Reconstruction Loss 0.004
# 122/2000  Reconstruction Loss 0.004
# 123/2000  Reconstruction Loss 0.004
# 124/2000  Reconstruction Loss 0.004
# 125/2000  Reconstruction Loss 0.003
# 126/2000  Reconstruction Loss 0.003
# 127/2000  Reconstruction Loss 0.003
# 128/2000  Reconstruction Loss 0.003
# 129/2000  Reconstruction Loss 0.003
# 130/2000  Reconstruction Loss 0.003
# 131/2000  Reconstruction Loss 0.003
# 132/2000  Reconstruction Loss 0.003
# 133/2000  Reconstruction Loss 0.003
# 134/2000  Reconstruction Loss 0.004
# 135/2000  Reconstruction Loss 0.003
# 136/2000  Reconstruction Loss 0.003
# 137/2000  Reconstruction Loss 0.003
# 138/2000  Reconstruction Loss 0.003
# 139/2000  Reconstruction Loss 0.003
# 140/2000  Reconstruction Loss 0.003
# 141/2000  Reconstruction Loss 0.003
# 142/2000  Reconstruction Loss 0.003
# 143/2000  Reconstruction Loss 0.003
# 144/2000  Reconstruction Loss 0.003
# 145/2000  Reconstruction Loss 0.003
# 146/2000  Reconstruction Loss 0.003
# 147/2000  Reconstruction Loss 0.003
# 148/2000  Reconstruction Loss 0.003
# 149/2000  Reconstruction Loss 0.003
# 150/2000  Reconstruction Loss 0.003
# 151/2000  Reconstruction Loss 0.003
# 152/2000  Reconstruction Loss 0.003
# 153/2000  Reconstruction Loss 0.003
# 154/2000  Reconstruction Loss 0.003
# 155/2000  Reconstruction Loss 0.003
# 156/2000  Reconstruction Loss 0.003
# 157/2000  Reconstruction Loss 0.003
# 158/2000  Reconstruction Loss 0.003
# 159/2000  Reconstruction Loss 0.003
# 160/2000  Reconstruction Loss 0.003
# 161/2000  Reconstruction Loss 0.003
# 162/2000  Reconstruction Loss 0.003
# 163/2000  Reconstruction Loss 0.003
# 164/2000  Reconstruction Loss 0.003
# 165/2000  Reconstruction Loss 0.003
# 166/2000  Reconstruction Loss 0.003
# 167/2000  Reconstruction Loss 0.003
# 168/2000  Reconstruction Loss 0.003
# 169/2000  Reconstruction Loss 0.003
# 170/2000  Reconstruction Loss 0.003
# 171/2000  Reconstruction Loss 0.003
# 172/2000  Reconstruction Loss 0.003
# 173/2000  Reconstruction Loss 0.003
# 174/2000  Reconstruction Loss 0.003
# 175/2000  Reconstruction Loss 0.003
# 176/2000  Reconstruction Loss 0.003
# 177/2000  Reconstruction Loss 0.003
# 178/2000  Reconstruction Loss 0.003
# 179/2000  Reconstruction Loss 0.003
# 180/2000  Reconstruction Loss 0.003
# 181/2000  Reconstruction Loss 0.003
# 182/2000  Reconstruction Loss 0.003
# 183/2000  Reconstruction Loss 0.003
# 184/2000  Reconstruction Loss 0.003
# 185/2000  Reconstruction Loss 0.003
# 186/2000  Reconstruction Loss 0.003
# 187/2000  Reconstruction Loss 0.003
# 188/2000  Reconstruction Loss 0.003
# 189/2000  Reconstruction Loss 0.003
# 190/2000  Reconstruction Loss 0.003
# 191/2000  Reconstruction Loss 0.003
# 192/2000  Reconstruction Loss 0.003
# 193/2000  Reconstruction Loss 0.003
# 194/2000  Reconstruction Loss 0.004
# 195/2000  Reconstruction Loss 0.003
# 196/2000  Reconstruction Loss 0.003
# 197/2000  Reconstruction Loss 0.003
# 198/2000  Reconstruction Loss 0.003
# 199/2000  Reconstruction Loss 0.003
# 200/2000  Reconstruction Loss 0.003
# 201/2000  Reconstruction Loss 0.003
# 202/2000  Reconstruction Loss 0.003
# 203/2000  Reconstruction Loss 0.003
# 204/2000  Reconstruction Loss 0.003
# 205/2000  Reconstruction Loss 0.003
# 206/2000  Reconstruction Loss 0.003
# 207/2000  Reconstruction Loss 0.003
# 208/2000  Reconstruction Loss 0.003
# 209/2000  Reconstruction Loss 0.003
# 210/2000  Reconstruction Loss 0.003
# 211/2000  Reconstruction Loss 0.003
# 212/2000  Reconstruction Loss 0.003
# 213/2000  Reconstruction Loss 0.003
# 214/2000  Reconstruction Loss 0.003
# 215/2000  Reconstruction Loss 0.003
# 216/2000  Reconstruction Loss 0.003
# 217/2000  Reconstruction Loss 0.003
# 218/2000  Reconstruction Loss 0.003
# 219/2000  Reconstruction Loss 0.003
# 220/2000  Reconstruction Loss 0.003
# 221/2000  Reconstruction Loss 0.003
# 222/2000  Reconstruction Loss 0.003
# 223/2000  Reconstruction Loss 0.003
# 224/2000  Reconstruction Loss 0.003
# 225/2000  Reconstruction Loss 0.003
# 226/2000  Reconstruction Loss 0.003
# 227/2000  Reconstruction Loss 0.003
# 228/2000  Reconstruction Loss 0.003
# 229/2000  Reconstruction Loss 0.003
# 230/2000  Reconstruction Loss 0.003
# 231/2000  Reconstruction Loss 0.003
# 232/2000  Reconstruction Loss 0.003
# 233/2000  Reconstruction Loss 0.003
# 234/2000  Reconstruction Loss 0.003
# 235/2000  Reconstruction Loss 0.003
# 236/2000  Reconstruction Loss 0.003
# 237/2000  Reconstruction Loss 0.003
# 238/2000  Reconstruction Loss 0.003
# 239/2000  Reconstruction Loss 0.003
# 240/2000  Reconstruction Loss 0.003
# 241/2000  Reconstruction Loss 0.003
# 242/2000  Reconstruction Loss 0.004
# 243/2000  Reconstruction Loss 0.003
# 244/2000  Reconstruction Loss 0.003
# 245/2000  Reconstruction Loss 0.004
# 246/2000  Reconstruction Loss 0.003
# 247/2000  Reconstruction Loss 0.003
# 248/2000  Reconstruction Loss 0.003
# 249/2000  Reconstruction Loss 0.003
# 250/2000  Reconstruction Loss 0.003
# 251/2000  Reconstruction Loss 0.003
# 252/2000  Reconstruction Loss 0.003
# 253/2000  Reconstruction Loss 0.003
# 254/2000  Reconstruction Loss 0.003
# 255/2000  Reconstruction Loss 0.003
# 256/2000  Reconstruction Loss 0.003
# 257/2000  Reconstruction Loss 0.003
# 258/2000  Reconstruction Loss 0.003
# 259/2000  Reconstruction Loss 0.003
# 260/2000  Reconstruction Loss 0.003
# 261/2000  Reconstruction Loss 0.003
# 262/2000  Reconstruction Loss 0.003
# 263/2000  Reconstruction Loss 0.003
# 264/2000  Reconstruction Loss 0.003
# 265/2000  Reconstruction Loss 0.003
# 266/2000  Reconstruction Loss 0.003
# 267/2000  Reconstruction Loss 0.003
# 268/2000  Reconstruction Loss 0.003
# 269/2000  Reconstruction Loss 0.003
# 270/2000  Reconstruction Loss 0.003
# 271/2000  Reconstruction Loss 0.003
# 272/2000  Reconstruction Loss 0.003
# 273/2000  Reconstruction Loss 0.003
# 274/2000  Reconstruction Loss 0.003
# 275/2000  Reconstruction Loss 0.003
# 276/2000  Reconstruction Loss 0.003
# 277/2000  Reconstruction Loss 0.003
# 278/2000  Reconstruction Loss 0.003
# 279/2000  Reconstruction Loss 0.003
# 280/2000  Reconstruction Loss 0.003
# 281/2000  Reconstruction Loss 0.003
# 282/2000  Reconstruction Loss 0.003
# 283/2000  Reconstruction Loss 0.003
# 284/2000  Reconstruction Loss 0.003
# 285/2000  Reconstruction Loss 0.003
# 286/2000  Reconstruction Loss 0.003
# 287/2000  Reconstruction Loss 0.003
# 288/2000  Reconstruction Loss 0.003
# 289/2000  Reconstruction Loss 0.003
# 290/2000  Reconstruction Loss 0.003
# 291/2000  Reconstruction Loss 0.003
# 292/2000  Reconstruction Loss 0.003
# 293/2000  Reconstruction Loss 0.003
# 294/2000  Reconstruction Loss 0.003
# 295/2000  Reconstruction Loss 0.003
# 296/2000  Reconstruction Loss 0.003
# 297/2000  Reconstruction Loss 0.003
# 298/2000  Reconstruction Loss 0.003
# 299/2000  Reconstruction Loss 0.003
# 300/2000  Reconstruction Loss 0.003
# 301/2000  Reconstruction Loss 0.003
# 302/2000  Reconstruction Loss 0.003
# 303/2000  Reconstruction Loss 0.003
# 304/2000  Reconstruction Loss 0.003
# 305/2000  Reconstruction Loss 0.003
# 306/2000  Reconstruction Loss 0.003
# 307/2000  Reconstruction Loss 0.003
# 308/2000  Reconstruction Loss 0.003
# 309/2000  Reconstruction Loss 0.003
# 310/2000  Reconstruction Loss 0.003
# 311/2000  Reconstruction Loss 0.003
# 312/2000  Reconstruction Loss 0.003
# 313/2000  Reconstruction Loss 0.003
# 314/2000  Reconstruction Loss 0.003
# 315/2000  Reconstruction Loss 0.003
# 316/2000  Reconstruction Loss 0.003
# 317/2000  Reconstruction Loss 0.003
# 318/2000  Reconstruction Loss 0.003
# 319/2000  Reconstruction Loss 0.003
# 320/2000  Reconstruction Loss 0.003
# 321/2000  Reconstruction Loss 0.003
# 322/2000  Reconstruction Loss 0.003
# 323/2000  Reconstruction Loss 0.003
# 324/2000  Reconstruction Loss 0.003
# 325/2000  Reconstruction Loss 0.003
# 326/2000  Reconstruction Loss 0.003
# 327/2000  Reconstruction Loss 0.003
# 328/2000  Reconstruction Loss 0.003
# 329/2000  Reconstruction Loss 0.003
# 330/2000  Reconstruction Loss 0.003
# 331/2000  Reconstruction Loss 0.003
# 332/2000  Reconstruction Loss 0.003
# 333/2000  Reconstruction Loss 0.003
# 334/2000  Reconstruction Loss 0.003
# 335/2000  Reconstruction Loss 0.002
# 336/2000  Reconstruction Loss 0.002
# 337/2000  Reconstruction Loss 0.003
# 338/2000  Reconstruction Loss 0.003
# 339/2000  Reconstruction Loss 0.003
# 340/2000  Reconstruction Loss 0.003
# 341/2000  Reconstruction Loss 0.003
# 342/2000  Reconstruction Loss 0.003
# 343/2000  Reconstruction Loss 0.003
# 344/2000  Reconstruction Loss 0.003
# 345/2000  Reconstruction Loss 0.003
# 346/2000  Reconstruction Loss 0.003
# 347/2000  Reconstruction Loss 0.003
# 348/2000  Reconstruction Loss 0.002
# 349/2000  Reconstruction Loss 0.003
# 350/2000  Reconstruction Loss 0.002
# 351/2000  Reconstruction Loss 0.002
# 352/2000  Reconstruction Loss 0.002
# 353/2000  Reconstruction Loss 0.002
# 354/2000  Reconstruction Loss 0.002
# 355/2000  Reconstruction Loss 0.002
# 356/2000  Reconstruction Loss 0.002
# 357/2000  Reconstruction Loss 0.003
# 358/2000  Reconstruction Loss 0.003
# 359/2000  Reconstruction Loss 0.003
# 360/2000  Reconstruction Loss 0.003
# 361/2000  Reconstruction Loss 0.003
# 362/2000  Reconstruction Loss 0.003
# 363/2000  Reconstruction Loss 0.003
# 364/2000  Reconstruction Loss 0.003
# 365/2000  Reconstruction Loss 0.003
# 366/2000  Reconstruction Loss 0.003
# 367/2000  Reconstruction Loss 0.002
# 368/2000  Reconstruction Loss 0.003
# 369/2000  Reconstruction Loss 0.003
# 370/2000  Reconstruction Loss 0.002
# 371/2000  Reconstruction Loss 0.003
# 372/2000  Reconstruction Loss 0.003
# 373/2000  Reconstruction Loss 0.002
# 374/2000  Reconstruction Loss 0.002
# 375/2000  Reconstruction Loss 0.002
# 376/2000  Reconstruction Loss 0.002
# 377/2000  Reconstruction Loss 0.002
# 378/2000  Reconstruction Loss 0.002
# 379/2000  Reconstruction Loss 0.002
# 380/2000  Reconstruction Loss 0.002
# 381/2000  Reconstruction Loss 0.002
# 382/2000  Reconstruction Loss 0.002
# 383/2000  Reconstruction Loss 0.002
# 384/2000  Reconstruction Loss 0.002
# 385/2000  Reconstruction Loss 0.002
# 386/2000  Reconstruction Loss 0.002
# 387/2000  Reconstruction Loss 0.002
# 388/2000  Reconstruction Loss 0.002
# 389/2000  Reconstruction Loss 0.002
# 390/2000  Reconstruction Loss 0.002
# 391/2000  Reconstruction Loss 0.002
# 392/2000  Reconstruction Loss 0.002
# 393/2000  Reconstruction Loss 0.002
# 394/2000  Reconstruction Loss 0.002
# 395/2000  Reconstruction Loss 0.002
# 396/2000  Reconstruction Loss 0.002
# 397/2000  Reconstruction Loss 0.002
# 398/2000  Reconstruction Loss 0.002
# 399/2000  Reconstruction Loss 0.003
# 400/2000  Reconstruction Loss 0.003
# 401/2000  Reconstruction Loss 0.003
# 402/2000  Reconstruction Loss 0.002
# 403/2000  Reconstruction Loss 0.003
# 404/2000  Reconstruction Loss 0.003
# 405/2000  Reconstruction Loss 0.003
# 406/2000  Reconstruction Loss 0.002
# 407/2000  Reconstruction Loss 0.003
# 408/2000  Reconstruction Loss 0.003
# 409/2000  Reconstruction Loss 0.002
# 410/2000  Reconstruction Loss 0.002
# 411/2000  Reconstruction Loss 0.002
# 412/2000  Reconstruction Loss 0.002
# 413/2000  Reconstruction Loss 0.002
# 414/2000  Reconstruction Loss 0.002
# 415/2000  Reconstruction Loss 0.002
# 416/2000  Reconstruction Loss 0.002
# 417/2000  Reconstruction Loss 0.002
# 418/2000  Reconstruction Loss 0.002
# 419/2000  Reconstruction Loss 0.002
# 420/2000  Reconstruction Loss 0.002
# 421/2000  Reconstruction Loss 0.002
# 422/2000  Reconstruction Loss 0.002
# 423/2000  Reconstruction Loss 0.002
# 424/2000  Reconstruction Loss 0.002
# 425/2000  Reconstruction Loss 0.002
# 426/2000  Reconstruction Loss 0.002
# 427/2000  Reconstruction Loss 0.002
# 428/2000  Reconstruction Loss 0.002
# 429/2000  Reconstruction Loss 0.002
# 430/2000  Reconstruction Loss 0.002
# 431/2000  Reconstruction Loss 0.002
# 432/2000  Reconstruction Loss 0.003
# 433/2000  Reconstruction Loss 0.003
# 434/2000  Reconstruction Loss 0.003
# 435/2000  Reconstruction Loss 0.002
# 436/2000  Reconstruction Loss 0.003
# 437/2000  Reconstruction Loss 0.003
# 438/2000  Reconstruction Loss 0.003
# 439/2000  Reconstruction Loss 0.002
# 440/2000  Reconstruction Loss 0.003
# 441/2000  Reconstruction Loss 0.002
# 442/2000  Reconstruction Loss 0.002
# 443/2000  Reconstruction Loss 0.002
# 444/2000  Reconstruction Loss 0.002
# 445/2000  Reconstruction Loss 0.002
# 446/2000  Reconstruction Loss 0.002
# 447/2000  Reconstruction Loss 0.002
# 448/2000  Reconstruction Loss 0.002
# 449/2000  Reconstruction Loss 0.002
# 450/2000  Reconstruction Loss 0.002
# 451/2000  Reconstruction Loss 0.002
# 452/2000  Reconstruction Loss 0.002
# 453/2000  Reconstruction Loss 0.002
# 454/2000  Reconstruction Loss 0.002
# 455/2000  Reconstruction Loss 0.002
# 456/2000  Reconstruction Loss 0.002
# 457/2000  Reconstruction Loss 0.002
# 458/2000  Reconstruction Loss 0.002
# 459/2000  Reconstruction Loss 0.002
# 460/2000  Reconstruction Loss 0.002
# 461/2000  Reconstruction Loss 0.002
# 462/2000  Reconstruction Loss 0.002
# 463/2000  Reconstruction Loss 0.002
# 464/2000  Reconstruction Loss 0.002
# 465/2000  Reconstruction Loss 0.002
# 466/2000  Reconstruction Loss 0.002
# 467/2000  Reconstruction Loss 0.002
# 468/2000  Reconstruction Loss 0.002
# 469/2000  Reconstruction Loss 0.002
# 470/2000  Reconstruction Loss 0.002
# 471/2000  Reconstruction Loss 0.002
# 472/2000  Reconstruction Loss 0.002
# 473/2000  Reconstruction Loss 0.002
# 474/2000  Reconstruction Loss 0.002
# 475/2000  Reconstruction Loss 0.002
# 476/2000  Reconstruction Loss 0.003
# 477/2000  Reconstruction Loss 0.003
# 478/2000  Reconstruction Loss 0.003
# 479/2000  Reconstruction Loss 0.002
# 480/2000  Reconstruction Loss 0.002
# 481/2000  Reconstruction Loss 0.003
# 482/2000  Reconstruction Loss 0.002
# 483/2000  Reconstruction Loss 0.002
# 484/2000  Reconstruction Loss 0.002
# 485/2000  Reconstruction Loss 0.002
# 486/2000  Reconstruction Loss 0.002
# 487/2000  Reconstruction Loss 0.002
# 488/2000  Reconstruction Loss 0.002
# 489/2000  Reconstruction Loss 0.002
# 490/2000  Reconstruction Loss 0.002
# 491/2000  Reconstruction Loss 0.002
# 492/2000  Reconstruction Loss 0.002
# 493/2000  Reconstruction Loss 0.002
# 494/2000  Reconstruction Loss 0.002
# 495/2000  Reconstruction Loss 0.002
# 496/2000  Reconstruction Loss 0.002
# 497/2000  Reconstruction Loss 0.002
# 498/2000  Reconstruction Loss 0.002
# 499/2000  Reconstruction Loss 0.002
# 500/2000  Reconstruction Loss 0.002
# 501/2000  Reconstruction Loss 0.002
# 502/2000  Reconstruction Loss 0.002
# 503/2000  Reconstruction Loss 0.002
# 504/2000  Reconstruction Loss 0.002
# 505/2000  Reconstruction Loss 0.002
# 506/2000  Reconstruction Loss 0.002
# 507/2000  Reconstruction Loss 0.002
# 508/2000  Reconstruction Loss 0.002
# 509/2000  Reconstruction Loss 0.002
# 510/2000  Reconstruction Loss 0.002
# 511/2000  Reconstruction Loss 0.002
# 512/2000  Reconstruction Loss 0.002
# 513/2000  Reconstruction Loss 0.002
# 514/2000  Reconstruction Loss 0.002
# 515/2000  Reconstruction Loss 0.002
# 516/2000  Reconstruction Loss 0.002
# 517/2000  Reconstruction Loss 0.002
# 518/2000  Reconstruction Loss 0.002
# 519/2000  Reconstruction Loss 0.002
# 520/2000  Reconstruction Loss 0.002
# 521/2000  Reconstruction Loss 0.002
# 522/2000  Reconstruction Loss 0.002
# 523/2000  Reconstruction Loss 0.002
# 524/2000  Reconstruction Loss 0.002
# 525/2000  Reconstruction Loss 0.002
# 526/2000  Reconstruction Loss 0.002
# 527/2000  Reconstruction Loss 0.002
# 528/2000  Reconstruction Loss 0.002
# 529/2000  Reconstruction Loss 0.002
# 530/2000  Reconstruction Loss 0.002
# 531/2000  Reconstruction Loss 0.002
# 532/2000  Reconstruction Loss 0.002
# 533/2000  Reconstruction Loss 0.002
# 534/2000  Reconstruction Loss 0.002
# 535/2000  Reconstruction Loss 0.002
# 536/2000  Reconstruction Loss 0.002
# 537/2000  Reconstruction Loss 0.002
# 538/2000  Reconstruction Loss 0.002
# 539/2000  Reconstruction Loss 0.002
# 540/2000  Reconstruction Loss 0.002
# 541/2000  Reconstruction Loss 0.002
# 542/2000  Reconstruction Loss 0.002
# 543/2000  Reconstruction Loss 0.002
# 544/2000  Reconstruction Loss 0.002
# 545/2000  Reconstruction Loss 0.002
# 546/2000  Reconstruction Loss 0.002
# 547/2000  Reconstruction Loss 0.002
# 548/2000  Reconstruction Loss 0.002
# 549/2000  Reconstruction Loss 0.002
# 550/2000  Reconstruction Loss 0.002
# 551/2000  Reconstruction Loss 0.002
# 552/2000  Reconstruction Loss 0.002
# 553/2000  Reconstruction Loss 0.002
# 554/2000  Reconstruction Loss 0.002
# 555/2000  Reconstruction Loss 0.002
# 556/2000  Reconstruction Loss 0.002
# 557/2000  Reconstruction Loss 0.002
# 558/2000  Reconstruction Loss 0.002
# 559/2000  Reconstruction Loss 0.003
# 560/2000  Reconstruction Loss 0.002
# 561/2000  Reconstruction Loss 0.002
# 562/2000  Reconstruction Loss 0.002
# 563/2000  Reconstruction Loss 0.002
# 564/2000  Reconstruction Loss 0.002
# 565/2000  Reconstruction Loss 0.002
# 566/2000  Reconstruction Loss 0.002
# 567/2000  Reconstruction Loss 0.002
# 568/2000  Reconstruction Loss 0.002
# 569/2000  Reconstruction Loss 0.002
# 570/2000  Reconstruction Loss 0.002
# 571/2000  Reconstruction Loss 0.002
# 572/2000  Reconstruction Loss 0.002
# 573/2000  Reconstruction Loss 0.002
# 574/2000  Reconstruction Loss 0.002
# 575/2000  Reconstruction Loss 0.002
# 576/2000  Reconstruction Loss 0.002
# 577/2000  Reconstruction Loss 0.002
# 578/2000  Reconstruction Loss 0.002
# 579/2000  Reconstruction Loss 0.002
# 580/2000  Reconstruction Loss 0.002
# 581/2000  Reconstruction Loss 0.002
# 582/2000  Reconstruction Loss 0.002
# 583/2000  Reconstruction Loss 0.002
# 584/2000  Reconstruction Loss 0.002
# 585/2000  Reconstruction Loss 0.002
# 586/2000  Reconstruction Loss 0.002
# 587/2000  Reconstruction Loss 0.002
# 588/2000  Reconstruction Loss 0.002
# 589/2000  Reconstruction Loss 0.002
# 590/2000  Reconstruction Loss 0.002
# 591/2000  Reconstruction Loss 0.002
# 592/2000  Reconstruction Loss 0.002
# 593/2000  Reconstruction Loss 0.002
# 594/2000  Reconstruction Loss 0.002
# 595/2000  Reconstruction Loss 0.002
# 596/2000  Reconstruction Loss 0.002
# 597/2000  Reconstruction Loss 0.002
# 598/2000  Reconstruction Loss 0.002
# 599/2000  Reconstruction Loss 0.002
# 600/2000  Reconstruction Loss 0.002
# 601/2000  Reconstruction Loss 0.002
# 602/2000  Reconstruction Loss 0.002
# 603/2000  Reconstruction Loss 0.002
# 604/2000  Reconstruction Loss 0.002
# 605/2000  Reconstruction Loss 0.002
# 606/2000  Reconstruction Loss 0.002
# 607/2000  Reconstruction Loss 0.002
# 608/2000  Reconstruction Loss 0.002
# 609/2000  Reconstruction Loss 0.002
# 610/2000  Reconstruction Loss 0.002
# 611/2000  Reconstruction Loss 0.002
# 612/2000  Reconstruction Loss 0.002
# 613/2000  Reconstruction Loss 0.002
# 614/2000  Reconstruction Loss 0.002
# 615/2000  Reconstruction Loss 0.002
# 616/2000  Reconstruction Loss 0.002
# 617/2000  Reconstruction Loss 0.002
# 618/2000  Reconstruction Loss 0.002
# 619/2000  Reconstruction Loss 0.002
# 620/2000  Reconstruction Loss 0.002
# 621/2000  Reconstruction Loss 0.002
# 622/2000  Reconstruction Loss 0.002
# 623/2000  Reconstruction Loss 0.002
# 624/2000  Reconstruction Loss 0.002
# 625/2000  Reconstruction Loss 0.002
# 626/2000  Reconstruction Loss 0.002
# 627/2000  Reconstruction Loss 0.002
# 628/2000  Reconstruction Loss 0.002
# 629/2000  Reconstruction Loss 0.002
# 630/2000  Reconstruction Loss 0.002
# 631/2000  Reconstruction Loss 0.002
# 632/2000  Reconstruction Loss 0.002
# 633/2000  Reconstruction Loss 0.002
# 634/2000  Reconstruction Loss 0.002
# 635/2000  Reconstruction Loss 0.002
# 636/2000  Reconstruction Loss 0.002
# 637/2000  Reconstruction Loss 0.002
# 638/2000  Reconstruction Loss 0.002
# 639/2000  Reconstruction Loss 0.002
# 640/2000  Reconstruction Loss 0.002
# 641/2000  Reconstruction Loss 0.002
# 642/2000  Reconstruction Loss 0.002
# 643/2000  Reconstruction Loss 0.002
# 644/2000  Reconstruction Loss 0.002
# 645/2000  Reconstruction Loss 0.002
# 646/2000  Reconstruction Loss 0.002
# 647/2000  Reconstruction Loss 0.002
# 648/2000  Reconstruction Loss 0.002
# 649/2000  Reconstruction Loss 0.002
# 650/2000  Reconstruction Loss 0.002
# 651/2000  Reconstruction Loss 0.002
# 652/2000  Reconstruction Loss 0.002
# 653/2000  Reconstruction Loss 0.002
# 654/2000  Reconstruction Loss 0.002
# 655/2000  Reconstruction Loss 0.002
# 656/2000  Reconstruction Loss 0.002
# 657/2000  Reconstruction Loss 0.002
# 658/2000  Reconstruction Loss 0.002
# 659/2000  Reconstruction Loss 0.002
# 660/2000  Reconstruction Loss 0.001
# 661/2000  Reconstruction Loss 0.002
# 662/2000  Reconstruction Loss 0.002
# 663/2000  Reconstruction Loss 0.002
# 664/2000  Reconstruction Loss 0.002
# 665/2000  Reconstruction Loss 0.001
# 666/2000  Reconstruction Loss 0.001
# 667/2000  Reconstruction Loss 0.002
# 668/2000  Reconstruction Loss 0.002
# 669/2000  Reconstruction Loss 0.002
# 670/2000  Reconstruction Loss 0.001
# 671/2000  Reconstruction Loss 0.001
# 672/2000  Reconstruction Loss 0.001
# 673/2000  Reconstruction Loss 0.001
# 674/2000  Reconstruction Loss 0.001
# 675/2000  Reconstruction Loss 0.001
# 676/2000  Reconstruction Loss 0.001
# 677/2000  Reconstruction Loss 0.001
# 678/2000  Reconstruction Loss 0.001
# 679/2000  Reconstruction Loss 0.002
# 680/2000  Reconstruction Loss 0.001
# 681/2000  Reconstruction Loss 0.001
# 682/2000  Reconstruction Loss 0.001
# 683/2000  Reconstruction Loss 0.001
# 684/2000  Reconstruction Loss 0.001
# 685/2000  Reconstruction Loss 0.002
# 686/2000  Reconstruction Loss 0.002
# 687/2000  Reconstruction Loss 0.002
# 688/2000  Reconstruction Loss 0.002
# 689/2000  Reconstruction Loss 0.001
# 690/2000  Reconstruction Loss 0.002
# 691/2000  Reconstruction Loss 0.002
# 692/2000  Reconstruction Loss 0.002
# 693/2000  Reconstruction Loss 0.001
# 694/2000  Reconstruction Loss 0.001
# 695/2000  Reconstruction Loss 0.001
# 696/2000  Reconstruction Loss 0.001
# 697/2000  Reconstruction Loss 0.001
# 698/2000  Reconstruction Loss 0.001
# 699/2000  Reconstruction Loss 0.001
# 700/2000  Reconstruction Loss 0.001
# 701/2000  Reconstruction Loss 0.001
# 702/2000  Reconstruction Loss 0.001
# 703/2000  Reconstruction Loss 0.001
# 704/2000  Reconstruction Loss 0.001
# 705/2000  Reconstruction Loss 0.001
# 706/2000  Reconstruction Loss 0.001
# 707/2000  Reconstruction Loss 0.001
# 708/2000  Reconstruction Loss 0.001
# 709/2000  Reconstruction Loss 0.001
# 710/2000  Reconstruction Loss 0.002
# 711/2000  Reconstruction Loss 0.002
# 712/2000  Reconstruction Loss 0.002
# 713/2000  Reconstruction Loss 0.002
# 714/2000  Reconstruction Loss 0.001
# 715/2000  Reconstruction Loss 0.001
# 716/2000  Reconstruction Loss 0.001
# 717/2000  Reconstruction Loss 0.001
# 718/2000  Reconstruction Loss 0.001
# 719/2000  Reconstruction Loss 0.001
# 720/2000  Reconstruction Loss 0.001
# 721/2000  Reconstruction Loss 0.001
# 722/2000  Reconstruction Loss 0.002
# 723/2000  Reconstruction Loss 0.001
# 724/2000  Reconstruction Loss 0.001
# 725/2000  Reconstruction Loss 0.001
# 726/2000  Reconstruction Loss 0.001
# 727/2000  Reconstruction Loss 0.001
# 728/2000  Reconstruction Loss 0.001
# 729/2000  Reconstruction Loss 0.001
# 730/2000  Reconstruction Loss 0.001
# 731/2000  Reconstruction Loss 0.001
# 732/2000  Reconstruction Loss 0.001
# 733/2000  Reconstruction Loss 0.001
# 734/2000  Reconstruction Loss 0.001
# 735/2000  Reconstruction Loss 0.001
# 736/2000  Reconstruction Loss 0.001
# 737/2000  Reconstruction Loss 0.001
# 738/2000  Reconstruction Loss 0.001
# 739/2000  Reconstruction Loss 0.001
# 740/2000  Reconstruction Loss 0.001
# 741/2000  Reconstruction Loss 0.001
# 742/2000  Reconstruction Loss 0.001
# 743/2000  Reconstruction Loss 0.001
# 744/2000  Reconstruction Loss 0.001
# 745/2000  Reconstruction Loss 0.001
# 746/2000  Reconstruction Loss 0.001
# 747/2000  Reconstruction Loss 0.001
# 748/2000  Reconstruction Loss 0.001
# 749/2000  Reconstruction Loss 0.001
# 750/2000  Reconstruction Loss 0.001
# 751/2000  Reconstruction Loss 0.001
# 752/2000  Reconstruction Loss 0.001
# 753/2000  Reconstruction Loss 0.001
# 754/2000  Reconstruction Loss 0.001
# 755/2000  Reconstruction Loss 0.001
# 756/2000  Reconstruction Loss 0.001
# 757/2000  Reconstruction Loss 0.001
# 758/2000  Reconstruction Loss 0.001
# 759/2000  Reconstruction Loss 0.001
# 760/2000  Reconstruction Loss 0.001
# 761/2000  Reconstruction Loss 0.001
# 762/2000  Reconstruction Loss 0.001
# 763/2000  Reconstruction Loss 0.001
# 764/2000  Reconstruction Loss 0.001
# 765/2000  Reconstruction Loss 0.001
# 766/2000  Reconstruction Loss 0.001
# 767/2000  Reconstruction Loss 0.001
# 768/2000  Reconstruction Loss 0.001
# 769/2000  Reconstruction Loss 0.001
# 770/2000  Reconstruction Loss 0.001
# 771/2000  Reconstruction Loss 0.001
# 772/2000  Reconstruction Loss 0.001
# 773/2000  Reconstruction Loss 0.001
# 774/2000  Reconstruction Loss 0.001
# 775/2000  Reconstruction Loss 0.001
# 776/2000  Reconstruction Loss 0.002
# 777/2000  Reconstruction Loss 0.001
# 778/2000  Reconstruction Loss 0.001
# 779/2000  Reconstruction Loss 0.001
# 780/2000  Reconstruction Loss 0.001
# 781/2000  Reconstruction Loss 0.001
# 782/2000  Reconstruction Loss 0.001
# 783/2000  Reconstruction Loss 0.001
# 784/2000  Reconstruction Loss 0.001
# 785/2000  Reconstruction Loss 0.001
# 786/2000  Reconstruction Loss 0.001
# 787/2000  Reconstruction Loss 0.001
# 788/2000  Reconstruction Loss 0.001
# 789/2000  Reconstruction Loss 0.001
# 790/2000  Reconstruction Loss 0.001
# 791/2000  Reconstruction Loss 0.001
# 792/2000  Reconstruction Loss 0.001
# 793/2000  Reconstruction Loss 0.001
# 794/2000  Reconstruction Loss 0.001
# 795/2000  Reconstruction Loss 0.001
# 796/2000  Reconstruction Loss 0.001
# 797/2000  Reconstruction Loss 0.001
# 798/2000  Reconstruction Loss 0.001
# 799/2000  Reconstruction Loss 0.001
# 800/2000  Reconstruction Loss 0.001
# 801/2000  Reconstruction Loss 0.001
# 802/2000  Reconstruction Loss 0.001
# 803/2000  Reconstruction Loss 0.001
# 804/2000  Reconstruction Loss 0.001
# 805/2000  Reconstruction Loss 0.001
# 806/2000  Reconstruction Loss 0.001
# 807/2000  Reconstruction Loss 0.001
# 808/2000  Reconstruction Loss 0.001
# 809/2000  Reconstruction Loss 0.001
# 810/2000  Reconstruction Loss 0.001
# 811/2000  Reconstruction Loss 0.001
# 812/2000  Reconstruction Loss 0.001
# 813/2000  Reconstruction Loss 0.001
# 814/2000  Reconstruction Loss 0.001
# 815/2000  Reconstruction Loss 0.001
# 816/2000  Reconstruction Loss 0.001
# 817/2000  Reconstruction Loss 0.001
# 818/2000  Reconstruction Loss 0.001
# 819/2000  Reconstruction Loss 0.001
# 820/2000  Reconstruction Loss 0.002
# 821/2000  Reconstruction Loss 0.002
# 822/2000  Reconstruction Loss 0.002
# 823/2000  Reconstruction Loss 0.002
# 824/2000  Reconstruction Loss 0.002
# 825/2000  Reconstruction Loss 0.002
# 826/2000  Reconstruction Loss 0.002
# 827/2000  Reconstruction Loss 0.002
# 828/2000  Reconstruction Loss 0.001
# 829/2000  Reconstruction Loss 0.001
# 830/2000  Reconstruction Loss 0.001
# 831/2000  Reconstruction Loss 0.001
# 832/2000  Reconstruction Loss 0.001
# 833/2000  Reconstruction Loss 0.001
# 834/2000  Reconstruction Loss 0.001
# 835/2000  Reconstruction Loss 0.001
# 836/2000  Reconstruction Loss 0.001
# 837/2000  Reconstruction Loss 0.001
# 838/2000  Reconstruction Loss 0.001
# 839/2000  Reconstruction Loss 0.001
# 840/2000  Reconstruction Loss 0.001
# 841/2000  Reconstruction Loss 0.001
# 842/2000  Reconstruction Loss 0.001
# 843/2000  Reconstruction Loss 0.001
# 844/2000  Reconstruction Loss 0.001
# 845/2000  Reconstruction Loss 0.001
# 846/2000  Reconstruction Loss 0.001
# 847/2000  Reconstruction Loss 0.001
# 848/2000  Reconstruction Loss 0.001
# 849/2000  Reconstruction Loss 0.001
# 850/2000  Reconstruction Loss 0.001
# 851/2000  Reconstruction Loss 0.001
# 852/2000  Reconstruction Loss 0.001
# 853/2000  Reconstruction Loss 0.001
# 854/2000  Reconstruction Loss 0.001
# 855/2000  Reconstruction Loss 0.001
# 856/2000  Reconstruction Loss 0.001
# 857/2000  Reconstruction Loss 0.001
# 858/2000  Reconstruction Loss 0.001
# 859/2000  Reconstruction Loss 0.001
# 860/2000  Reconstruction Loss 0.001
# 861/2000  Reconstruction Loss 0.001
# 862/2000  Reconstruction Loss 0.001
# 863/2000  Reconstruction Loss 0.001
# 864/2000  Reconstruction Loss 0.001
# 865/2000  Reconstruction Loss 0.001
# 866/2000  Reconstruction Loss 0.001
# 867/2000  Reconstruction Loss 0.001
# 868/2000  Reconstruction Loss 0.001
# 869/2000  Reconstruction Loss 0.001
# 870/2000  Reconstruction Loss 0.001
# 871/2000  Reconstruction Loss 0.001
# 872/2000  Reconstruction Loss 0.001
# 873/2000  Reconstruction Loss 0.001
# 874/2000  Reconstruction Loss 0.001
# 875/2000  Reconstruction Loss 0.001
# 876/2000  Reconstruction Loss 0.001
# 877/2000  Reconstruction Loss 0.001
# 878/2000  Reconstruction Loss 0.001
# 879/2000  Reconstruction Loss 0.001
# 880/2000  Reconstruction Loss 0.001
# 881/2000  Reconstruction Loss 0.001
# 882/2000  Reconstruction Loss 0.001
# 883/2000  Reconstruction Loss 0.001
# 884/2000  Reconstruction Loss 0.001
# 885/2000  Reconstruction Loss 0.001
# 886/2000  Reconstruction Loss 0.001
# 887/2000  Reconstruction Loss 0.001
# 888/2000  Reconstruction Loss 0.001
# 889/2000  Reconstruction Loss 0.001
# 890/2000  Reconstruction Loss 0.001
# 891/2000  Reconstruction Loss 0.001
# 892/2000  Reconstruction Loss 0.001
# 893/2000  Reconstruction Loss 0.001
# 894/2000  Reconstruction Loss 0.001
# 895/2000  Reconstruction Loss 0.001
# 896/2000  Reconstruction Loss 0.001
# 897/2000  Reconstruction Loss 0.001
# 898/2000  Reconstruction Loss 0.001
# 899/2000  Reconstruction Loss 0.001
# 900/2000  Reconstruction Loss 0.001
# 901/2000  Reconstruction Loss 0.001
# 902/2000  Reconstruction Loss 0.001
# 903/2000  Reconstruction Loss 0.001
# 904/2000  Reconstruction Loss 0.001
# 905/2000  Reconstruction Loss 0.001
# 906/2000  Reconstruction Loss 0.001
# 907/2000  Reconstruction Loss 0.001
# 908/2000  Reconstruction Loss 0.001
# 909/2000  Reconstruction Loss 0.001
# 910/2000  Reconstruction Loss 0.001
# 911/2000  Reconstruction Loss 0.001
# 912/2000  Reconstruction Loss 0.001
# 913/2000  Reconstruction Loss 0.001
# 914/2000  Reconstruction Loss 0.001
# 915/2000  Reconstruction Loss 0.001
# 916/2000  Reconstruction Loss 0.001
# 917/2000  Reconstruction Loss 0.001
# 918/2000  Reconstruction Loss 0.001
# 919/2000  Reconstruction Loss 0.001
# 920/2000  Reconstruction Loss 0.001
# 921/2000  Reconstruction Loss 0.001
# 922/2000  Reconstruction Loss 0.001
# 923/2000  Reconstruction Loss 0.001
# 924/2000  Reconstruction Loss 0.001
# 925/2000  Reconstruction Loss 0.001
# 926/2000  Reconstruction Loss 0.001
# 927/2000  Reconstruction Loss 0.001
# 928/2000  Reconstruction Loss 0.001
# 929/2000  Reconstruction Loss 0.001
# 930/2000  Reconstruction Loss 0.001
# 931/2000  Reconstruction Loss 0.001
# 932/2000  Reconstruction Loss 0.001
# 933/2000  Reconstruction Loss 0.001
# 934/2000  Reconstruction Loss 0.001
# 935/2000  Reconstruction Loss 0.001
# 936/2000  Reconstruction Loss 0.001
# 937/2000  Reconstruction Loss 0.001
# 938/2000  Reconstruction Loss 0.001
# 939/2000  Reconstruction Loss 0.001
# 940/2000  Reconstruction Loss 0.001
# 941/2000  Reconstruction Loss 0.001
# 942/2000  Reconstruction Loss 0.001
# 943/2000  Reconstruction Loss 0.001
# 944/2000  Reconstruction Loss 0.001
# 945/2000  Reconstruction Loss 0.001
# 946/2000  Reconstruction Loss 0.001
# 947/2000  Reconstruction Loss 0.001
# 948/2000  Reconstruction Loss 0.001
# 949/2000  Reconstruction Loss 0.001
# 950/2000  Reconstruction Loss 0.001
# 951/2000  Reconstruction Loss 0.001
# 952/2000  Reconstruction Loss 0.001
# 953/2000  Reconstruction Loss 0.001
# 954/2000  Reconstruction Loss 0.001
# 955/2000  Reconstruction Loss 0.001
# 956/2000  Reconstruction Loss 0.001
# 957/2000  Reconstruction Loss 0.001
# 958/2000  Reconstruction Loss 0.001
# 959/2000  Reconstruction Loss 0.001
# 960/2000  Reconstruction Loss 0.001
# 961/2000  Reconstruction Loss 0.001
# 962/2000  Reconstruction Loss 0.001
# 963/2000  Reconstruction Loss 0.001
# 964/2000  Reconstruction Loss 0.001
# 965/2000  Reconstruction Loss 0.001
# 966/2000  Reconstruction Loss 0.001
# 967/2000  Reconstruction Loss 0.001
# 968/2000  Reconstruction Loss 0.001
# 969/2000  Reconstruction Loss 0.001
# 970/2000  Reconstruction Loss 0.001
# 971/2000  Reconstruction Loss 0.001
# 972/2000  Reconstruction Loss 0.001
# 973/2000  Reconstruction Loss 0.001
# 974/2000  Reconstruction Loss 0.001
# 975/2000  Reconstruction Loss 0.001
# 976/2000  Reconstruction Loss 0.001
# 977/2000  Reconstruction Loss 0.001
# 978/2000  Reconstruction Loss 0.001
# 979/2000  Reconstruction Loss 0.001
# 980/2000  Reconstruction Loss 0.001
# 981/2000  Reconstruction Loss 0.001
# 982/2000  Reconstruction Loss 0.001
# 983/2000  Reconstruction Loss 0.001
# 984/2000  Reconstruction Loss 0.001
# 985/2000  Reconstruction Loss 0.001
# 986/2000  Reconstruction Loss 0.001
# 987/2000  Reconstruction Loss 0.001
# 988/2000  Reconstruction Loss 0.001
# 989/2000  Reconstruction Loss 0.001
# 990/2000  Reconstruction Loss 0.001
# 991/2000  Reconstruction Loss 0.001
# 992/2000  Reconstruction Loss 0.001
# 993/2000  Reconstruction Loss 0.001
# 994/2000  Reconstruction Loss 0.001
# 995/2000  Reconstruction Loss 0.001
# 996/2000  Reconstruction Loss 0.001
# 997/2000  Reconstruction Loss 0.001
# 998/2000  Reconstruction Loss 0.001
# 999/2000  Reconstruction Loss 0.001
# 1000/2000  Reconstruction Loss 0.001
# 1001/2000  Reconstruction Loss 0.001
# 1002/2000  Reconstruction Loss 0.001
# 1003/2000  Reconstruction Loss 0.001
# 1004/2000  Reconstruction Loss 0.001
# 1005/2000  Reconstruction Loss 0.001
# 1006/2000  Reconstruction Loss 0.001
# 1007/2000  Reconstruction Loss 0.001
# 1008/2000  Reconstruction Loss 0.001
# 1009/2000  Reconstruction Loss 0.001
# 1010/2000  Reconstruction Loss 0.001
# 1011/2000  Reconstruction Loss 0.001
# 1012/2000  Reconstruction Loss 0.001
# 1013/2000  Reconstruction Loss 0.001
# 1014/2000  Reconstruction Loss 0.001
# 1015/2000  Reconstruction Loss 0.001
# 1016/2000  Reconstruction Loss 0.001
# 1017/2000  Reconstruction Loss 0.001
# 1018/2000  Reconstruction Loss 0.001
# 1019/2000  Reconstruction Loss 0.001
# 1020/2000  Reconstruction Loss 0.001
# 1021/2000  Reconstruction Loss 0.001
# 1022/2000  Reconstruction Loss 0.001
# 1023/2000  Reconstruction Loss 0.001
# 1024/2000  Reconstruction Loss 0.001
# 1025/2000  Reconstruction Loss 0.001
# 1026/2000  Reconstruction Loss 0.001
# 1027/2000  Reconstruction Loss 0.001
# 1028/2000  Reconstruction Loss 0.001
# 1029/2000  Reconstruction Loss 0.001
# 1030/2000  Reconstruction Loss 0.001
# 1031/2000  Reconstruction Loss 0.001
# 1032/2000  Reconstruction Loss 0.001
# 1033/2000  Reconstruction Loss 0.001
# 1034/2000  Reconstruction Loss 0.001
# 1035/2000  Reconstruction Loss 0.001
# 1036/2000  Reconstruction Loss 0.001
# 1037/2000  Reconstruction Loss 0.001
# 1038/2000  Reconstruction Loss 0.001
# 1039/2000  Reconstruction Loss 0.001
# 1040/2000  Reconstruction Loss 0.001
# 1041/2000  Reconstruction Loss 0.001
# 1042/2000  Reconstruction Loss 0.001
# 1043/2000  Reconstruction Loss 0.001
# 1044/2000  Reconstruction Loss 0.000
# 1045/2000  Reconstruction Loss 0.000
# 1046/2000  Reconstruction Loss 0.000
# 1047/2000  Reconstruction Loss 0.000
# 1048/2000  Reconstruction Loss 0.001
# 1049/2000  Reconstruction Loss 0.000
# 1050/2000  Reconstruction Loss 0.001
# 1051/2000  Reconstruction Loss 0.001
# 1052/2000  Reconstruction Loss 0.001
# 1053/2000  Reconstruction Loss 0.001
# 1054/2000  Reconstruction Loss 0.001
# 1055/2000  Reconstruction Loss 0.000
# 1056/2000  Reconstruction Loss 0.000
# 1057/2000  Reconstruction Loss 0.000
# 1058/2000  Reconstruction Loss 0.000
# 1059/2000  Reconstruction Loss 0.000
# 1060/2000  Reconstruction Loss 0.000
# 1061/2000  Reconstruction Loss 0.000
# 1062/2000  Reconstruction Loss 0.000
# 1063/2000  Reconstruction Loss 0.000
# 1064/2000  Reconstruction Loss 0.000
# 1065/2000  Reconstruction Loss 0.000
# 1066/2000  Reconstruction Loss 0.000
# 1067/2000  Reconstruction Loss 0.000
# 1068/2000  Reconstruction Loss 0.000
# 1069/2000  Reconstruction Loss 0.001
# 1070/2000  Reconstruction Loss 0.001
# 1071/2000  Reconstruction Loss 0.001
# 1072/2000  Reconstruction Loss 0.002
# 1073/2000  Reconstruction Loss 0.001
# 1074/2000  Reconstruction Loss 0.001
# 1075/2000  Reconstruction Loss 0.001
# 1076/2000  Reconstruction Loss 0.001
# 1077/2000  Reconstruction Loss 0.001
# 1078/2000  Reconstruction Loss 0.001
# 1079/2000  Reconstruction Loss 0.002
# 1080/2000  Reconstruction Loss 0.002
# 1081/2000  Reconstruction Loss 0.002
# 1082/2000  Reconstruction Loss 0.002
# 1083/2000  Reconstruction Loss 0.001
# 1084/2000  Reconstruction Loss 0.002
# 1085/2000  Reconstruction Loss 0.001
# 1086/2000  Reconstruction Loss 0.001
# 1087/2000  Reconstruction Loss 0.001
# 1088/2000  Reconstruction Loss 0.001
# 1089/2000  Reconstruction Loss 0.001
# 1090/2000  Reconstruction Loss 0.001
# 1091/2000  Reconstruction Loss 0.001
# 1092/2000  Reconstruction Loss 0.001
# 1093/2000  Reconstruction Loss 0.001
# 1094/2000  Reconstruction Loss 0.001
# 1095/2000  Reconstruction Loss 0.001
# 1096/2000  Reconstruction Loss 0.001
# 1097/2000  Reconstruction Loss 0.001
# 1098/2000  Reconstruction Loss 0.001
# 1099/2000  Reconstruction Loss 0.001
# 1100/2000  Reconstruction Loss 0.001
# 1101/2000  Reconstruction Loss 0.001
# 1102/2000  Reconstruction Loss 0.001
# 1103/2000  Reconstruction Loss 0.001
# 1104/2000  Reconstruction Loss 0.001
# 1105/2000  Reconstruction Loss 0.001
# 1106/2000  Reconstruction Loss 0.001
# 1107/2000  Reconstruction Loss 0.001
# 1108/2000  Reconstruction Loss 0.001
# 1109/2000  Reconstruction Loss 0.001
# 1110/2000  Reconstruction Loss 0.001
# 1111/2000  Reconstruction Loss 0.001
# 1112/2000  Reconstruction Loss 0.001
# 1113/2000  Reconstruction Loss 0.001
# 1114/2000  Reconstruction Loss 0.001
# 1115/2000  Reconstruction Loss 0.001
# 1116/2000  Reconstruction Loss 0.001
# 1117/2000  Reconstruction Loss 0.001
# 1118/2000  Reconstruction Loss 0.001
# 1119/2000  Reconstruction Loss 0.001
# 1120/2000  Reconstruction Loss 0.001
# 1121/2000  Reconstruction Loss 0.001
# 1122/2000  Reconstruction Loss 0.001
# 1123/2000  Reconstruction Loss 0.001
# 1124/2000  Reconstruction Loss 0.001
# 1125/2000  Reconstruction Loss 0.001
# 1126/2000  Reconstruction Loss 0.001
# 1127/2000  Reconstruction Loss 0.001
# 1128/2000  Reconstruction Loss 0.001
# 1129/2000  Reconstruction Loss 0.001
# 1130/2000  Reconstruction Loss 0.001
# 1131/2000  Reconstruction Loss 0.001
# 1132/2000  Reconstruction Loss 0.001
# 1133/2000  Reconstruction Loss 0.001
# 1134/2000  Reconstruction Loss 0.001
# 1135/2000  Reconstruction Loss 0.001
# 1136/2000  Reconstruction Loss 0.001
# 1137/2000  Reconstruction Loss 0.001
# 1138/2000  Reconstruction Loss 0.000
# 1139/2000  Reconstruction Loss 0.000
# 1140/2000  Reconstruction Loss 0.000
# 1141/2000  Reconstruction Loss 0.000
# 1142/2000  Reconstruction Loss 0.000
# 1143/2000  Reconstruction Loss 0.000
# 1144/2000  Reconstruction Loss 0.000
# 1145/2000  Reconstruction Loss 0.000
# 1146/2000  Reconstruction Loss 0.000
# 1147/2000  Reconstruction Loss 0.000
# 1148/2000  Reconstruction Loss 0.000
# 1149/2000  Reconstruction Loss 0.000
# 1150/2000  Reconstruction Loss 0.000
# 1151/2000  Reconstruction Loss 0.000
# 1152/2000  Reconstruction Loss 0.000
# 1153/2000  Reconstruction Loss 0.000
# 1154/2000  Reconstruction Loss 0.000
# 1155/2000  Reconstruction Loss 0.000
# 1156/2000  Reconstruction Loss 0.000
# 1157/2000  Reconstruction Loss 0.000
# 1158/2000  Reconstruction Loss 0.000
# 1159/2000  Reconstruction Loss 0.000
# 1160/2000  Reconstruction Loss 0.000
# 1161/2000  Reconstruction Loss 0.001
# 1162/2000  Reconstruction Loss 0.001
# 1163/2000  Reconstruction Loss 0.001
# 1164/2000  Reconstruction Loss 0.000
# 1165/2000  Reconstruction Loss 0.000
# 1166/2000  Reconstruction Loss 0.000
# 1167/2000  Reconstruction Loss 0.001
# 1168/2000  Reconstruction Loss 0.000
# 1169/2000  Reconstruction Loss 0.000
# 1170/2000  Reconstruction Loss 0.000
# 1171/2000  Reconstruction Loss 0.000
# 1172/2000  Reconstruction Loss 0.001
# 1173/2000  Reconstruction Loss 0.000
# 1174/2000  Reconstruction Loss 0.000
# 1175/2000  Reconstruction Loss 0.000
# 1176/2000  Reconstruction Loss 0.000
# 1177/2000  Reconstruction Loss 0.000
# 1178/2000  Reconstruction Loss 0.000
# 1179/2000  Reconstruction Loss 0.000
# 1180/2000  Reconstruction Loss 0.000
# 1181/2000  Reconstruction Loss 0.000
# 1182/2000  Reconstruction Loss 0.000
# 1183/2000  Reconstruction Loss 0.000
# 1184/2000  Reconstruction Loss 0.000
# 1185/2000  Reconstruction Loss 0.000
# 1186/2000  Reconstruction Loss 0.000
# 1187/2000  Reconstruction Loss 0.000
# 1188/2000  Reconstruction Loss 0.000
# 1189/2000  Reconstruction Loss 0.000
# 1190/2000  Reconstruction Loss 0.000
# 1191/2000  Reconstruction Loss 0.000
# 1192/2000  Reconstruction Loss 0.000
# 1193/2000  Reconstruction Loss 0.001
# 1194/2000  Reconstruction Loss 0.001
# 1195/2000  Reconstruction Loss 0.000
# 1196/2000  Reconstruction Loss 0.001
# 1197/2000  Reconstruction Loss 0.001
# 1198/2000  Reconstruction Loss 0.001
# 1199/2000  Reconstruction Loss 0.001
# 1200/2000  Reconstruction Loss 0.001
# 1201/2000  Reconstruction Loss 0.000
# 1202/2000  Reconstruction Loss 0.001
# 1203/2000  Reconstruction Loss 0.001
# 1204/2000  Reconstruction Loss 0.001
# 1205/2000  Reconstruction Loss 0.001
# 1206/2000  Reconstruction Loss 0.001
# 1207/2000  Reconstruction Loss 0.001
# 1208/2000  Reconstruction Loss 0.000
# 1209/2000  Reconstruction Loss 0.000
# 1210/2000  Reconstruction Loss 0.000
# 1211/2000  Reconstruction Loss 0.000
# 1212/2000  Reconstruction Loss 0.000
# 1213/2000  Reconstruction Loss 0.000
# 1214/2000  Reconstruction Loss 0.000
# 1215/2000  Reconstruction Loss 0.000
# 1216/2000  Reconstruction Loss 0.000
# 1217/2000  Reconstruction Loss 0.000
# 1218/2000  Reconstruction Loss 0.000
# 1219/2000  Reconstruction Loss 0.000
# 1220/2000  Reconstruction Loss 0.000
# 1221/2000  Reconstruction Loss 0.000
# 1222/2000  Reconstruction Loss 0.000
# 1223/2000  Reconstruction Loss 0.000
# 1224/2000  Reconstruction Loss 0.000
# 1225/2000  Reconstruction Loss 0.000
# 1226/2000  Reconstruction Loss 0.000
# 1227/2000  Reconstruction Loss 0.000
# 1228/2000  Reconstruction Loss 0.000
# 1229/2000  Reconstruction Loss 0.000
# 1230/2000  Reconstruction Loss 0.000
# 1231/2000  Reconstruction Loss 0.000
# 1232/2000  Reconstruction Loss 0.000
# 1233/2000  Reconstruction Loss 0.000
# 1234/2000  Reconstruction Loss 0.001
# 1235/2000  Reconstruction Loss 0.001
# 1236/2000  Reconstruction Loss 0.001
# 1237/2000  Reconstruction Loss 0.001
# 1238/2000  Reconstruction Loss 0.001
# 1239/2000  Reconstruction Loss 0.001
# 1240/2000  Reconstruction Loss 0.001
# 1241/2000  Reconstruction Loss 0.001
# 1242/2000  Reconstruction Loss 0.001
# 1243/2000  Reconstruction Loss 0.001
# 1244/2000  Reconstruction Loss 0.001
# 1245/2000  Reconstruction Loss 0.001
# 1246/2000  Reconstruction Loss 0.001
# 1247/2000  Reconstruction Loss 0.001
# 1248/2000  Reconstruction Loss 0.001
# 1249/2000  Reconstruction Loss 0.001
# 1250/2000  Reconstruction Loss 0.001
# 1251/2000  Reconstruction Loss 0.001
# 1252/2000  Reconstruction Loss 0.001
# 1253/2000  Reconstruction Loss 0.000
# 1254/2000  Reconstruction Loss 0.000
# 1255/2000  Reconstruction Loss 0.000
# 1256/2000  Reconstruction Loss 0.000
# 1257/2000  Reconstruction Loss 0.000
# 1258/2000  Reconstruction Loss 0.000
# 1259/2000  Reconstruction Loss 0.000
# 1260/2000  Reconstruction Loss 0.000
# 1261/2000  Reconstruction Loss 0.000
# 1262/2000  Reconstruction Loss 0.000
# 1263/2000  Reconstruction Loss 0.000
# 1264/2000  Reconstruction Loss 0.000
# 1265/2000  Reconstruction Loss 0.000
# 1266/2000  Reconstruction Loss 0.000
# 1267/2000  Reconstruction Loss 0.000
# 1268/2000  Reconstruction Loss 0.000
# 1269/2000  Reconstruction Loss 0.000
# 1270/2000  Reconstruction Loss 0.000
# 1271/2000  Reconstruction Loss 0.000
# 1272/2000  Reconstruction Loss 0.000
# 1273/2000  Reconstruction Loss 0.000
# 1274/2000  Reconstruction Loss 0.000
# 1275/2000  Reconstruction Loss 0.000
# 1276/2000  Reconstruction Loss 0.000
# 1277/2000  Reconstruction Loss 0.000
# 1278/2000  Reconstruction Loss 0.000
# 1279/2000  Reconstruction Loss 0.001
# 1280/2000  Reconstruction Loss 0.001
# 1281/2000  Reconstruction Loss 0.001
# 1282/2000  Reconstruction Loss 0.000
# 1283/2000  Reconstruction Loss 0.000
# 1284/2000  Reconstruction Loss 0.000
# 1285/2000  Reconstruction Loss 0.000
# 1286/2000  Reconstruction Loss 0.000
# 1287/2000  Reconstruction Loss 0.000
# 1288/2000  Reconstruction Loss 0.000
# 1289/2000  Reconstruction Loss 0.000
# 1290/2000  Reconstruction Loss 0.000
# 1291/2000  Reconstruction Loss 0.000
# 1292/2000  Reconstruction Loss 0.000
# 1293/2000  Reconstruction Loss 0.000
# 1294/2000  Reconstruction Loss 0.000
# 1295/2000  Reconstruction Loss 0.000
# 1296/2000  Reconstruction Loss 0.000
# 1297/2000  Reconstruction Loss 0.000
# 1298/2000  Reconstruction Loss 0.000
# 1299/2000  Reconstruction Loss 0.000
# 1300/2000  Reconstruction Loss 0.000
# 1301/2000  Reconstruction Loss 0.000
# 1302/2000  Reconstruction Loss 0.000
# 1303/2000  Reconstruction Loss 0.000
# 1304/2000  Reconstruction Loss 0.000
# 1305/2000  Reconstruction Loss 0.000
# 1306/2000  Reconstruction Loss 0.000
# 1307/2000  Reconstruction Loss 0.000
# 1308/2000  Reconstruction Loss 0.000
# 1309/2000  Reconstruction Loss 0.000
# 1310/2000  Reconstruction Loss 0.000
# 1311/2000  Reconstruction Loss 0.000
# 1312/2000  Reconstruction Loss 0.000
# 1313/2000  Reconstruction Loss 0.000
# 1314/2000  Reconstruction Loss 0.000
# 1315/2000  Reconstruction Loss 0.000
# 1316/2000  Reconstruction Loss 0.000
# 1317/2000  Reconstruction Loss 0.000
# 1318/2000  Reconstruction Loss 0.000
# 1319/2000  Reconstruction Loss 0.000
# 1320/2000  Reconstruction Loss 0.000
# 1321/2000  Reconstruction Loss 0.000
# 1322/2000  Reconstruction Loss 0.000
# 1323/2000  Reconstruction Loss 0.000
# 1324/2000  Reconstruction Loss 0.000
# 1325/2000  Reconstruction Loss 0.000
# 1326/2000  Reconstruction Loss 0.000
# 1327/2000  Reconstruction Loss 0.000
# 1328/2000  Reconstruction Loss 0.000
# 1329/2000  Reconstruction Loss 0.000
# 1330/2000  Reconstruction Loss 0.000
# 1331/2000  Reconstruction Loss 0.000
# 1332/2000  Reconstruction Loss 0.000
# 1333/2000  Reconstruction Loss 0.000
# 1334/2000  Reconstruction Loss 0.000
# 1335/2000  Reconstruction Loss 0.000
# 1336/2000  Reconstruction Loss 0.000
# 1337/2000  Reconstruction Loss 0.000
# 1338/2000  Reconstruction Loss 0.000
# 1339/2000  Reconstruction Loss 0.000
# 1340/2000  Reconstruction Loss 0.000
# 1341/2000  Reconstruction Loss 0.000
# 1342/2000  Reconstruction Loss 0.000
# 1343/2000  Reconstruction Loss 0.000
# 1344/2000  Reconstruction Loss 0.000
# 1345/2000  Reconstruction Loss 0.000
# 1346/2000  Reconstruction Loss 0.000
# 1347/2000  Reconstruction Loss 0.000
# 1348/2000  Reconstruction Loss 0.000
# 1349/2000  Reconstruction Loss 0.000
# 1350/2000  Reconstruction Loss 0.000
# 1351/2000  Reconstruction Loss 0.000
# 1352/2000  Reconstruction Loss 0.001
# 1353/2000  Reconstruction Loss 0.001
# 1354/2000  Reconstruction Loss 0.001
# 1355/2000  Reconstruction Loss 0.001
# 1356/2000  Reconstruction Loss 0.001
# 1357/2000  Reconstruction Loss 0.001
# 1358/2000  Reconstruction Loss 0.002
# 1359/2000  Reconstruction Loss 0.004
# 1360/2000  Reconstruction Loss 0.005
# 1361/2000  Reconstruction Loss 0.018
# 1362/2000  Reconstruction Loss 0.029
# 1363/2000  Reconstruction Loss 0.015
# 1364/2000  Reconstruction Loss 0.012
# 1365/2000  Reconstruction Loss 0.009
# 1366/2000  Reconstruction Loss 0.008
# 1367/2000  Reconstruction Loss 0.009
# 1368/2000  Reconstruction Loss 0.007
# 1369/2000  Reconstruction Loss 0.007
# 1370/2000  Reconstruction Loss 0.006
# 1371/2000  Reconstruction Loss 0.006
# 1372/2000  Reconstruction Loss 0.005
# 1373/2000  Reconstruction Loss 0.005
# 1374/2000  Reconstruction Loss 0.005
# 1375/2000  Reconstruction Loss 0.005
# 1376/2000  Reconstruction Loss 0.005
# 1377/2000  Reconstruction Loss 0.005
# 1378/2000  Reconstruction Loss 0.004
# 1379/2000  Reconstruction Loss 0.004
# 1380/2000  Reconstruction Loss 0.004
# 1381/2000  Reconstruction Loss 0.004
# 1382/2000  Reconstruction Loss 0.004
# 1383/2000  Reconstruction Loss 0.004
# 1384/2000  Reconstruction Loss 0.004
# 1385/2000  Reconstruction Loss 0.004
# 1386/2000  Reconstruction Loss 0.004
# 1387/2000  Reconstruction Loss 0.004
# 1388/2000  Reconstruction Loss 0.004
# 1389/2000  Reconstruction Loss 0.004
# 1390/2000  Reconstruction Loss 0.004
# 1391/2000  Reconstruction Loss 0.004
# 1392/2000  Reconstruction Loss 0.004
# 1393/2000  Reconstruction Loss 0.004
# 1394/2000  Reconstruction Loss 0.004
# 1395/2000  Reconstruction Loss 0.004
# 1396/2000  Reconstruction Loss 0.004
# 1397/2000  Reconstruction Loss 0.004
# 1398/2000  Reconstruction Loss 0.004
# 1399/2000  Reconstruction Loss 0.004
# 1400/2000  Reconstruction Loss 0.004
# 1401/2000  Reconstruction Loss 0.004
# 1402/2000  Reconstruction Loss 0.004
# 1403/2000  Reconstruction Loss 0.004
# 1404/2000  Reconstruction Loss 0.004
# 1405/2000  Reconstruction Loss 0.004
# 1406/2000  Reconstruction Loss 0.004
# 1407/2000  Reconstruction Loss 0.004
# 1408/2000  Reconstruction Loss 0.004
# 1409/2000  Reconstruction Loss 0.004
# 1410/2000  Reconstruction Loss 0.004
# 1411/2000  Reconstruction Loss 0.004
# 1412/2000  Reconstruction Loss 0.004
# 1413/2000  Reconstruction Loss 0.004
# 1414/2000  Reconstruction Loss 0.004
# 1415/2000  Reconstruction Loss 0.004
# 1416/2000  Reconstruction Loss 0.003
# 1417/2000  Reconstruction Loss 0.003
# 1418/2000  Reconstruction Loss 0.003
# 1419/2000  Reconstruction Loss 0.003
# 1420/2000  Reconstruction Loss 0.003
# 1421/2000  Reconstruction Loss 0.003
# 1422/2000  Reconstruction Loss 0.003
# 1423/2000  Reconstruction Loss 0.003
# 1424/2000  Reconstruction Loss 0.003
# 1425/2000  Reconstruction Loss 0.003
# 1426/2000  Reconstruction Loss 0.003
# 1427/2000  Reconstruction Loss 0.003
# 1428/2000  Reconstruction Loss 0.003
# 1429/2000  Reconstruction Loss 0.003
# 1430/2000  Reconstruction Loss 0.003
# 1431/2000  Reconstruction Loss 0.003
# 1432/2000  Reconstruction Loss 0.003
# 1433/2000  Reconstruction Loss 0.003
# 1434/2000  Reconstruction Loss 0.003
# 1435/2000  Reconstruction Loss 0.003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# セル4 を /home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb in <cell line: 42>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a> # training phrase
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a> model.train()
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a> for batch_images in load_mri_images(path_data, batch_size):
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a>     optimizer.zero_grad()
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=48'>49</a>     batch_images = batch_images.to(device)
#
# セル4 を /home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb in load_mri_images(path, batch_size)
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a> image = np.array(image.dataobj)
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a> depth = image.shape[2]
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a> image = torch.Tensor(image)[:, :, depth//2-32:depth//2+32]  # (512, 512, 64)
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a> image = (image - image.min()) / (image.max() - image.min())
#      <a href='vscode-notebook-cell://ssh-remote%2Bubuntu/home/nakai-yu/dev/imsegnet/notebook/3dvae.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a> image = torch.reshape(image, (1, 1, 512, 512, 64))
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt 
import numpy as np
import nibabel as ni 
import torch

def display_image(x, y):
    assert x.shape == y.shape
    if x.dim() == 5:
        x = torch.reshape(x, (x.shape[0], 64, 64, 8)).cpu().detach().numpy()
        y = torch.reshape(y, (y.shape[0], 64, 64, 8)).cpu().detach().numpy()
        for i in range(len(x)):
            rows = 2
            columns = 1
            fig=plt.figure()
            for idx in range(rows*columns):
                fig.add_subplot(rows, columns, idx+1)
                if idx < columns:
                    plt.imshow(x[i, :, :, 4], cmap="gray", origin="lower")
                else:
                    plt.imshow(y[i, :, :, 4], cmap="gray", origin="lower")
            plt.show()

# %%
import nibabel as ni
import numpy as np
import os, glob
import torch 
import csv
from tqdm import tqdm
import matplotlib.pyplot as plt 

batch_size = 1
path_data = "../ircad-dataset/test"
path_model = "./checkpoint/3drec-cont_1400.pt"

log = print
np.random.seed(10)
torch.manual_seed(10)

criterion_dis = nn.MSELoss()

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(" GPU is activated" if device else " CPU is activated")
no_images = len(glob.glob(path_data + "/*.nii"))
print("Number of MRI images: ", no_images)

model = torch.load(path_model)
model.to(device)
total_loss = 0
    
# interfere phrase
model.eval()
with torch.no_grad():
    for batch_images in load_mri_images(path_data, batch_size):
        batch_images = batch_images.to(device)
        y = model(batch_images[:, :, :, :, 4])

        # Measure loss
        loss = criterion(batch_images, y)

        total_loss += loss.item() * batch_images.shape[0]

        # display
        display_image(batch_images, y)

print("Loss: {:.4f}".format(total_loss/ no_images))
# Out:
#  GPU is activated
# Number of MRI images:  6
# Loss: 0.0061
